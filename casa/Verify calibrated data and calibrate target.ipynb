# %%
msfile = 'ngc3621_fixvis.ms'
prefix = 'ngc3621_fixvis'

target='NGC3621'
g_cal='1117-248'
b_cal='0408-65'
f_cal='0408-65'

ktable = prefix + '.K'
btable = prefix + '.B'
gtable = prefix + '.G'
ftable = prefix + '.flux'

# %% [markdown]
# ### Verify efficiency of calibration and flagging

# %%
plotms(vis=msfile,
       xaxis='real',
       yaxis='imag',
       correlation='XX,YY',
       xdatacolumn='corrected',
       ydatacolumn='corrected',
       field=f_cal,
       avgscan=False,
       coloraxis='scan')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065433_27" data-target="#log1585065433_27" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065433_27">2020-03-24 15:57:07	INFO	plotms::::
# <br>2020-03-24 15:57:07	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:57:07	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:57:07	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        plotindex=0,xaxis="real",xdatacolumn="corrected",xframe="",xinterp="",
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        yaxis="imag",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        selectdata=True,field="0408-65",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        symboloutline=False,coloraxis="scan",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:57:07	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:57:09	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:57:09	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache	START     Current memory usage: 2293.09 kilobytes.
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache	Caching for the new plot: Imag(20):corrected vs. Real(19):corrected...
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache	Data selection will yield a total of 5632200 plottable points (flagged and unflagged).
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0579741 GB of memory (10.2933 bytes/point).
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache+	This is 0.355399% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache	Loading chunks......
# <br>2020-03-24 15:57:10	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:57:10	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:57:10	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:57:10	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:57:10	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:57:10	INFO	PlotMS::load_cache+	Real:corrected: 9.2399 to 25.4281 (unflagged); ; -40.4226 to 2265.25 (flagged).
# <br>2020-03-24 15:57:10	INFO	PlotMS::load_cache+	Imag:corrected: -7.47922 to 8.01905 (unflagged); -39.4177 to 38.7078(flagged).
# <br>2020-03-24 15:57:10	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:57:09	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +58594.4 kilobytes.
# <br>2020-03-24 15:57:10	INFO	PlotMS::plot	Plotting 2389960 unflagged points.
# <br>2020-03-24 15:57:10	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:57:10	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:57:10	INFO	QPExporter::export	START     Current memory usage: 61354.1 kilobytes.
# <br>2020-03-24 15:57:10	INFO	QPExporter::export	END       Time: +3 seconds.  Memory: +45.4062 kilobytes.
# <br>2020-03-24 15:57:13	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:57:13	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:57:13	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile,
       xaxis='real',
       yaxis='imag',
       correlation='XX,YY',
       xdatacolumn='corrected',
       ydatacolumn='corrected',
       field=g_cal,
       avgscan=False,
       coloraxis='scan')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065442_61" data-target="#log1585065442_61" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065442_61">2020-03-24 15:57:13	INFO	plotms::::
# <br>2020-03-24 15:57:13	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:57:13	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:57:13	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        plotindex=0,xaxis="real",xdatacolumn="corrected",xframe="",xinterp="",
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        yaxis="imag",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        selectdata=True,field="1117-248",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        symboloutline=False,coloraxis="scan",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:57:13	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:57:16	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache	START     Current memory usage: 5603.67 kilobytes.
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache	Caching for the new plot: Imag(20):corrected vs. Real(19):corrected...
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache	Data selection will yield a total of 5594400 plottable points (flagged and unflagged).
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.057585 GB of memory (10.2933 bytes/point).
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache+	This is 0.353014% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache	Loading chunks......
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache+	Real:corrected: -6.9944 to 11.7941 (unflagged); ; -23.2407 to 2921.61 (flagged).
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache+	Imag:corrected: -9.68412 to 8.5237 (unflagged); -20.5912 to 18.225(flagged).
# <br>2020-03-24 15:57:17	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:57:16	INFO	PlotMS::load_cache	END       Time: +0 seconds.  Memory: +57008.1 kilobytes.
# <br>2020-03-24 15:57:17	INFO	PlotMS::plot	Plotting 2373920 unflagged points.
# <br>2020-03-24 15:57:17	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:57:20	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:57:20	INFO	QPExporter::export	START     Current memory usage: 62752.1 kilobytes.
# <br>2020-03-24 15:57:20	INFO	QPExporter::export	END       Time: +3 seconds.  Memory: +1.5625 kilobytes.
# <br>2020-03-24 15:57:23	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:57:23	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:57:23	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile,
       xaxis='amp',
       yaxis='phase',
       correlation='XX,YY',
       xdatacolumn='corrected',
       ydatacolumn='corrected',
       field=f_cal,
       avgscan=False,
       coloraxis='corr')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065453_49" data-target="#log1585065453_49" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065453_49">2020-03-24 15:57:23	INFO	plotms::::
# <br>2020-03-24 15:57:23	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:57:23	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:57:23	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        plotindex=0,xaxis="amp",xdatacolumn="corrected",xframe="",xinterp="",
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        yaxis="phase",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        selectdata=True,field="0408-65",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        symboloutline=False,coloraxis="corr",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:57:23	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:57:25	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache	START     Current memory usage: 5629.08 kilobytes.
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache	Caching for the new plot: Phase(18):corrected vs. Amp(17):corrected...
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache	Data selection will yield a total of 5632200 plottable points (flagged and unflagged).
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0579741 GB of memory (10.2933 bytes/point).
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache+	This is 0.355399% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache	Loading chunks......
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache+	Amp:corrected: 9.27178 to 25.446 (unflagged); ; 9.55745 to 2265.25 (flagged).
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache+	Phase:corrected: -25.5627 to 27.7117 (unflagged); -180 to 180(flagged).
# <br>2020-03-24 15:57:26	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:57:25	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +57388.9 kilobytes.
# <br>2020-03-24 15:57:26	INFO	PlotMS::plot	Plotting 2389960 unflagged points.
# <br>2020-03-24 15:57:26	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:57:30	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:57:30	INFO	QPExporter::export	START     Current memory usage: 63158.2 kilobytes.
# <br>2020-03-24 15:57:30	INFO	QPExporter::export	END       Time: +4 seconds.  Memory: +1.59375 kilobytes.
# <br>2020-03-24 15:57:33	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:57:33	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:57:33	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile,
       xaxis='uvwave',
       yaxis='amp',
       correlation='XX,YY',
       xdatacolumn='corrected',
       ydatacolumn='corrected',
       field=f_cal,
       avgscan=False,
       coloraxis='corr')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065465_19" data-target="#log1585065465_19" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065465_19">2020-03-24 15:57:34	INFO	plotms::::
# <br>2020-03-24 15:57:34	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:57:34	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:57:34	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        plotindex=0,xaxis="uvwave",xdatacolumn="corrected",xframe="",xinterp="",
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        yaxis="amp",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        selectdata=True,field="0408-65",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        symboloutline=False,coloraxis="corr",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:57:34	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:57:37	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache	START     Current memory usage: 5644.48 kilobytes.
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):corrected vs. UVwave(29)...
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache	Data selection will yield a total of 5632200 plottable points (flagged and unflagged).
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0579741 GB of memory (10.2933 bytes/point).
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache+	This is 0.355399% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:57:38	INFO	PlotMS::load_cache	Loading chunks......
# <br>2020-03-24 15:57:38	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:57:38	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:57:38	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:57:38	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:57:38	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:57:38	INFO	PlotMS::load_cache+	UVwave: 200.315 to 1492.67 (unflagged); ; 0 to 2768.78 (flagged).
# <br>2020-03-24 15:57:38	INFO	PlotMS::load_cache+	Amp:corrected: 9.27178 to 25.446 (unflagged); 9.55745 to 2265.25(flagged).
# <br>2020-03-24 15:57:38	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:57:37	INFO	PlotMS::load_cache	END       Time: +2 seconds.  Memory: +57384.5 kilobytes.
# <br>2020-03-24 15:57:38	INFO	PlotMS::plot	Plotting 2389960 unflagged points.
# <br>2020-03-24 15:57:38	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:57:42	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:57:42	INFO	QPExporter::export	START     Current memory usage: 63199.9 kilobytes.
# <br>2020-03-24 15:57:42	INFO	QPExporter::export	END       Time: +4 seconds.  Memory: +2.53125 kilobytes.
# <br>2020-03-24 15:57:45	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:57:45	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:57:45	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile,
       xaxis='uvwave',
       yaxis='phase',
       correlation='XX,YY',
       xdatacolumn='corrected',
       ydatacolumn='corrected',
       field=f_cal,
       avgscan=False,
       coloraxis='corr')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065476_92" data-target="#log1585065476_92" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065476_92">2020-03-24 15:57:45	INFO	plotms::::
# <br>2020-03-24 15:57:45	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:57:45	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:57:45	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        plotindex=0,xaxis="uvwave",xdatacolumn="corrected",xframe="",xinterp="",
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        yaxis="phase",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        selectdata=True,field="0408-65",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        symboloutline=False,coloraxis="corr",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:57:45	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:57:49	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache	START     Current memory usage: 5690.48 kilobytes.
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache	Caching for the new plot: Phase(18):corrected vs. UVwave(29)...
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache	Data selection will yield a total of 5632200 plottable points (flagged and unflagged).
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0579741 GB of memory (10.2933 bytes/point).
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache+	This is 0.355399% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache	Loading chunks......
# <br>2020-03-24 15:57:50	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:57:50	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:57:50	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:57:50	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:57:50	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:57:50	INFO	PlotMS::load_cache+	UVwave: 200.315 to 1492.67 (unflagged); ; 0 to 2768.78 (flagged).
# <br>2020-03-24 15:57:50	INFO	PlotMS::load_cache+	Phase:corrected: -25.5627 to 27.7117 (unflagged); -180 to 180(flagged).
# <br>2020-03-24 15:57:50	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:57:49	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +57384.8 kilobytes.
# <br>2020-03-24 15:57:50	INFO	PlotMS::plot	Plotting 2389960 unflagged points.
# <br>2020-03-24 15:57:50	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:57:53	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:57:53	INFO	QPExporter::export	START     Current memory usage: 63216.1 kilobytes.
# <br>2020-03-24 15:57:53	INFO	QPExporter::export	END       Time: +3 seconds.  Memory: +2.04688 kilobytes.
# <br>2020-03-24 15:57:57	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:57:57	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:57:57	INFO	plotms::::+	##########################################
# </div>

# %% [markdown]
# ### Inspect data for flagging after antenna based calibration

# %%
plotms(vis=msfile,
       xaxis='scan',
       yaxis='amp',
       correlation='XX,YY',
       xdatacolumn='corrected',
       ydatacolumn='corrected',
       field=f_cal+','+g_cal,
       avgscan=False,
       coloraxis='field')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065492_58" data-target="#log1585065492_58" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065492_58">2020-03-24 15:57:57	INFO	plotms::::
# <br>2020-03-24 15:57:57	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:57:57	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:57:57	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        plotindex=0,xaxis="scan",xdatacolumn="corrected",xframe="",xinterp="",
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        yaxis="amp",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        selectdata=True,field="0408-65,1117-248",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        symboloutline=False,coloraxis="field",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:57:57	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:58:00	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache	START     Current memory usage: 5703.42 kilobytes.
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):corrected vs. Scan(0)...
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:58:01	INFO	PlotMS::load_cache	Data selection will yield a total of 11226600 plottable points (flagged and unflagged).
# <br>2020-03-24 15:58:01	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0706527 GB of memory (6.29333 bytes/point).
# <br>2020-03-24 15:58:01	INFO	PlotMS::load_cache+	This is 0.433123% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:58:01	INFO	PlotMS::load_cache	Loading chunks......
# <br>2020-03-24 15:58:01	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:58:01	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:58:01	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:58:01	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:58:02	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:58:02	INFO	PlotMS::load_cache+	Scan: 1 to 11 (unflagged); ; 1 to 11 (flagged).
# <br>2020-03-24 15:58:02	INFO	PlotMS::load_cache+	Amp:corrected: 0.00122014 to 25.446 (unflagged); 0.00421208 to 2921.61(flagged).
# <br>2020-03-24 15:58:02	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:58:00	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +70384.7 kilobytes.
# <br>2020-03-24 15:58:02	INFO	PlotMS::plot	Plotting 4763880 unflagged points.
# <br>2020-03-24 15:58:02	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:07	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:58:07	INFO	QPExporter::export	START     Current memory usage: 76226.2 kilobytes.
# <br>2020-03-24 15:58:07	INFO	QPExporter::export	END       Time: +5 seconds.  Memory: +1.54688 kilobytes.
# <br>2020-03-24 15:58:13	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:13	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:58:13	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile,
       xaxis='baseline',
       yaxis='amp',
       correlation='XX,YY',
       xdatacolumn='corrected',
       ydatacolumn='corrected',
       field=f_cal+','+g_cal,
       avgscan=False,
       coloraxis='field')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065510_83" data-target="#log1585065510_83" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065510_83">2020-03-24 15:58:13	INFO	plotms::::
# <br>2020-03-24 15:58:13	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:58:13	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:58:13	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        plotindex=0,xaxis="baseline",xdatacolumn="corrected",xframe="",xinterp="",
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        yaxis="amp",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        selectdata=True,field="0408-65,1117-248",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        symboloutline=False,coloraxis="field",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:58:13	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:58:18	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache	START     Current memory usage: 5713.61 kilobytes.
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):corrected vs. Baseline(11)...
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache	Data selection will yield a total of 11226600 plottable points (flagged and unflagged).
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0706527 GB of memory (6.29333 bytes/point).
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache+	This is 0.433123% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache	Loading chunks......
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache+	Baseline: 1 to 19 (unflagged); ; 0 to 25 (flagged).
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache+	Amp:corrected: 0.00122014 to 25.446 (unflagged); 0.00421208 to 2921.61(flagged).
# <br>2020-03-24 15:58:19	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:58:18	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +70482.9 kilobytes.
# <br>2020-03-24 15:58:19	INFO	PlotMS::plot	Plotting 4763880 unflagged points.
# <br>2020-03-24 15:58:19	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:25	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:58:25	INFO	QPExporter::export	START     Current memory usage: 76333 kilobytes.
# <br>2020-03-24 15:58:25	INFO	QPExporter::export	END       Time: +5 seconds.  Memory: +1.57812 kilobytes.
# <br>2020-03-24 15:58:31	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:31	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:58:31	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile,
       xaxis='channel',
       yaxis='phase',
       averagedata=True,
       avgtime='3300',
       ydatacolumn='corrected',
       avgbaseline=True,
       correlation='XX,YY',
       field=','.join((f_cal,g_cal)),
       coloraxis='field')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065518_57" data-target="#log1585065518_57" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065518_57">2020-03-24 15:58:31	INFO	plotms::::
# <br>2020-03-24 15:58:31	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:58:31	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:58:31	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        plotindex=0,xaxis="channel",xdatacolumn="",xframe="",xinterp="",
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        yaxis="phase",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        selectdata=True,field="0408-65,1117-248",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        avgtime="3300",avgscan=False,avgfield=False,avgbaseline=True,avgantenna=False,
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        symboloutline=False,coloraxis="field",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:58:31	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:58:36	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache	START     Current memory usage: 5824.05 kilobytes.
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache	Data Averaging:
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache+	 Using VECTOR averaging.
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache+	 Time: 3300 seconds.  Scan: false;  Field: false
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache+	 All Baselines: true
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache	Caching for the new plot: Phase(18):corrected vs. Channel(5)...
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache	Data selection will yield a total of 226800 plottable points (flagged and unflagged).
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.00142733 GB of memory (6.29333 bytes/point).
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache+	This is 0.00874997% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache	Loading chunks with averaging.....
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache+	Channel: 0 to 899 (unflagged); ; 30 to 839 (flagged).
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache+	Phase:corrected: -8.24162 to 13.302 (unflagged); -2.01284 to 2.01647(flagged).
# <br>2020-03-24 15:58:38	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:58:36	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +432.672 kilobytes.
# <br>2020-03-24 15:58:38	INFO	PlotMS::plot	Plotting 9624 unflagged points.
# <br>2020-03-24 15:58:38	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:38	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:58:38	INFO	QPExporter::export	START     Current memory usage: 6397.97 kilobytes.
# <br>2020-03-24 15:58:38	INFO	QPExporter::export	END       Time: +0 seconds.  Memory: +2.28125 kilobytes.
# <br>2020-03-24 15:58:39	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:39	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:58:39	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile,
       xaxis='channel',
       yaxis='amp',
       correlation='XX,YY',
       ydatacolumn='corrected',
       field=','.join((f_cal,g_cal)),
       coloraxis='field',
       averagedata=True,
       avgtime='3300',
       avgbaseline=True)
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065520_76" data-target="#log1585065520_76" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065520_76">2020-03-24 15:58:39	INFO	plotms::::
# <br>2020-03-24 15:58:39	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:58:39	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:58:39	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        plotindex=0,xaxis="channel",xdatacolumn="",xframe="",xinterp="",
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        yaxis="amp",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        selectdata=True,field="0408-65,1117-248",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        avgtime="3300",avgscan=False,avgfield=False,avgbaseline=True,avgantenna=False,
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        symboloutline=False,coloraxis="field",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:58:39	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:58:39	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache	START     Current memory usage: 6081.84 kilobytes.
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache	Data Averaging:
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache+	 Using VECTOR averaging.
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache+	 Time: 3300 seconds.  Scan: false;  Field: false
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache+	 All Baselines: true
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):corrected vs. Channel(5)...
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache	Data selection will yield a total of 226800 plottable points (flagged and unflagged).
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.00142733 GB of memory (6.29333 bytes/point).
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache+	This is 0.00874997% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache	Loading chunks with averaging.....
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache+	Channel: 0 to 899 (unflagged); ; 30 to 839 (flagged).
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache+	Amp:corrected: 1.60032 to 17.1081 (unflagged); 172.471 to 339.825(flagged).
# <br>2020-03-24 15:58:40	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:58:39	INFO	PlotMS::load_cache	END       Time: +2 seconds.  Memory: +429.281 kilobytes.
# <br>2020-03-24 15:58:40	INFO	PlotMS::plot	Plotting 9624 unflagged points.
# <br>2020-03-24 15:58:40	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:41	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:58:41	INFO	QPExporter::export	START     Current memory usage: 6653.86 kilobytes.
# <br>2020-03-24 15:58:41	INFO	QPExporter::export	END       Time: +0 seconds.  Memory: +1.96875 kilobytes.
# <br>2020-03-24 15:58:41	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:41	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:58:41	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile,
       xaxis='time',
       yaxis='amp',
       correlation='XX,YY',
       ydatacolumn='corrected',
       field=','.join((f_cal,g_cal)),
       coloraxis='field',
       averagedata=True,
       avgbaseline=True,
       avgchannel='4096')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065522_51" data-target="#log1585065522_51" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065522_51">2020-03-24 15:58:41	INFO	plotms::::
# <br>2020-03-24 15:58:41	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:58:41	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:58:41	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        plotindex=0,xaxis="time",xdatacolumn="",xframe="",xinterp="",
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        yaxis="amp",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        selectdata=True,field="0408-65,1117-248",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="4096",
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=True,avgantenna=False,
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        symboloutline=False,coloraxis="field",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:58:41	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:58:41	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache	START     Current memory usage: 6335.75 kilobytes.
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache	Data Averaging:
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache+	 Using VECTOR averaging.
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache+	 Channel: 4096 channels
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache+	 All Baselines: true
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):corrected vs. Time(2)...
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache	Data selection will yield a total of 12474 plottable points (flagged and unflagged).
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.000163944 GB of memory (13.1429 bytes/point).
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache+	This is 0.00100503% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache	Loading chunks with averaging.....
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache+	Time: 4.99838e+09 to 4.99838e+09 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache+	Amp:corrected: 1.95931 to 17.1064 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:42	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:58:41	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +10205.3 kilobytes.
# <br>2020-03-24 15:58:42	INFO	PlotMS::plot	Plotting 594 unflagged points.
# <br>2020-03-24 15:58:42	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:42	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:58:42	INFO	QPExporter::export	START     Current memory usage: 16687.1 kilobytes.
# <br>2020-03-24 15:58:42	INFO	QPExporter::export	END       Time: +0 seconds.  Memory: +1.875 kilobytes.
# <br>2020-03-24 15:58:42	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:42	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:58:42	INFO	plotms::::+	##########################################
# </div>

# %% [markdown]
# ### Inspect target after antenna based calibration

# %%
applycal(vis=msfile,
         field=target,
         gaintable=[ftable, btable, ktable],
         gainfield=[g_cal, b_cal, f_cal],
         interp=['', 'nearest', ''],
         calwt=False,
         applymode='calflag')
# Out:
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065524_28" data-target="#log1585065524_28" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065524_28">2020-03-24 15:58:43	INFO	applycal::::
# <br>2020-03-24 15:58:43	INFO	applycal::::+	##########################################
# <br>2020-03-24 15:58:43	INFO	applycal::::+	##### Begin Task: applycal           #####
# <br>2020-03-24 15:58:43	INFO	applycal::::	applycal(vis="ngc3621_fixvis.ms",field="NGC3621",spw="",intent="",selectdata=True,
# <br>2020-03-24 15:58:43	INFO	applycal::::+	        timerange="",uvrange="",antenna="",scan="",observation="",
# <br>2020-03-24 15:58:43	INFO	applycal::::+	        msselect="",docallib=False,callib="",gaintable=['ngc3621_fixvis.flux', 'ngc3621_fixvis.B', 'ngc3621_fixvis.K'],gainfield=['1117-248', '0408-65', '0408-65'],
# <br>2020-03-24 15:58:43	INFO	applycal::::+	        interp=['', 'nearest', ''],spwmap=[],calwt=False,parang=False,applymode="calflag",
# <br>2020-03-24 15:58:43	INFO	applycal::::+	        flagbackup=True)
# <br>2020-03-24 15:58:43	INFO	applycal::calibrater::open	****Using NEW VI2-driven calibrater tool****
# <br>2020-03-24 15:58:43	INFO	applycal::calibrater::open	Opening MS: ngc3621_fixvis.ms for calibration.
# <br>2020-03-24 15:58:43	INFO	applycal::Calibrater::	Initializing nominal selection to the whole MS.
# <br>2020-03-24 15:58:43	INFO	applycal::AgentFlagger::open	Table type is Measurement Set
# <br>2020-03-24 15:58:43	INFO	FlagVersion::saveFlagVersion	Creating new backup flag file called applycal_6
# <br>2020-03-24 15:58:43	INFO	calibrater::setdata	Beginning selectvis--(MSSelection version)-------
# <br>2020-03-24 15:58:43	INFO	calibrater::reset	Reseting solve/apply state
# <br>2020-03-24 15:58:43	INFO	Calibrater::selectvis	Performing selection on MeasurementSet
# <br>2020-03-24 15:58:43	INFO	Calibrater::selectvis+	 Selecting on field: 'NGC3621'
# <br>2020-03-24 15:58:43	INFO	Calibrater::selectvis	By selection 15687 rows are reduced to 9450
# <br>2020-03-24 15:58:43	INFO	Calibrater::selectvis	Frequency selection: Selecting all channels in all spws.
# <br>2020-03-24 15:58:43	INFO	calibrater::setdata	chanmode=none nchan=1 start=0 step=1 mStart='0km/s' mStep='0km/s' msSelect=''
# <br>2020-03-24 15:58:43	INFO	calibrater::setapply	Beginning setapply--(MSSelection version)-------
# <br>2020-03-24 15:58:43	INFO	Calibrater::setapply(type, applypar)	Arranging to APPLY:
# <br>2020-03-24 15:58:43	INFO	Calibrater::setapply(type, applypar)	.   G Jones: table=ngc3621_fixvis.flux select= interp=linear spwmap=[-1] calWt=false
# <br>2020-03-24 15:58:43	INFO	calibrater::setapply	Beginning setapply--(MSSelection version)-------
# <br>2020-03-24 15:58:43	INFO	Calibrater::setapply(type, applypar)	Arranging to APPLY:
# <br>2020-03-24 15:58:43	INFO	Calibrater::setapply(type, applypar)	.   B Jones: table=ngc3621_fixvis.B select= interp=nearest,linear spwmap=[-1] calWt=false
# <br>2020-03-24 15:58:43	INFO	calibrater::setapply	Beginning setapply--(MSSelection version)-------
# <br>2020-03-24 15:58:43	INFO	Calibrater::setapply(type, applypar)	Arranging to APPLY:
# <br>2020-03-24 15:58:43	INFO	Calibrater::setapply(type, applypar)	.   K Jones: table=ngc3621_fixvis.K select= interp=linear spwmap=[-1] calWt=false
# <br>2020-03-24 15:58:43	INFO	calibrater::correct	Beginning correct---------------------------
# <br>2020-03-24 15:58:43	INFO	Calibrater::correct2 (VI2/VB2)	The following calibration terms are arranged for apply:
# <br>2020-03-24 15:58:43	INFO	Calibrater::correct2 (VI2/VB2)	.   B Jones: table=ngc3621_fixvis.B select= interp=nearest,linear spwmap=[-1] calWt=false
# <br>2020-03-24 15:58:43	INFO	Calibrater::correct2 (VI2/VB2)	.   K Jones: table=ngc3621_fixvis.K select= interp=linear spwmap=[-1] calWt=false
# <br>2020-03-24 15:58:43	INFO	Calibrater::correct2 (VI2/VB2)	.   G Jones: table=ngc3621_fixvis.flux select= interp=linear spwmap=[-1] calWt=false
# <br>2020-03-24 15:58:44	INFO	calibrater::correct	Finished correcting.
# <br>2020-03-24 15:58:44	INFO	applycal::::	Calibration apply flagging statistics (among calibrateable spws):
# <br>2020-03-24 15:58:44	INFO	applycal::::	  Total visibilities selected for correction (ncorr x nchan x nrow summed over spws) = 17010000
# <br>2020-03-24 15:58:44	INFO	applycal::::	  Flags:
# <br>2020-03-24 15:58:44	INFO	applycal::::	   B Jones: In: 8910000 / 17010000   (52.380952381%) --> Out: 8910000 / 17010000   (52.380952381%) (ngc3621_fixvis.B)
# <br>2020-03-24 15:58:44	INFO	applycal::::	   K Jones: In: 8910000 / 17010000   (52.380952381%) --> Out: 8910000 / 17010000   (52.380952381%) (ngc3621_fixvis.K)
# <br>2020-03-24 15:58:44	INFO	applycal::::	   G Jones: In: 8910000 / 17010000   (52.380952381%) --> Out: 8910000 / 17010000   (52.380952381%) (ngc3621_fixvis.flux)
# <br>2020-03-24 15:58:44	INFO	applycal::::	CASA Version 5.5.0-149
# <br>2020-03-24 15:58:44	INFO	applycal::::
# <br>2020-03-24 15:58:44	INFO	applycal::::	##### End Task: applycal             #####
# <br>2020-03-24 15:58:44	INFO	applycal::::+	##########################################
# </div>

# %%
plotms(vis=msfile,
       xaxis='channel',
       yaxis='phase',
       ydatacolumn='corrected',
       correlation='XX,YY',
       field=target,
       averagedata=True,
       avgtime='3300',
       avgbaseline=True,
       coloraxis='scan')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065526_95" data-target="#log1585065526_95" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065526_95">2020-03-24 15:58:44	INFO	plotms::::
# <br>2020-03-24 15:58:44	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:58:44	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:58:44	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        plotindex=0,xaxis="channel",xdatacolumn="",xframe="",xinterp="",
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        yaxis="phase",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        selectdata=True,field="NGC3621",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        avgtime="3300",avgscan=False,avgfield=False,avgbaseline=True,avgantenna=False,
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        symboloutline=False,coloraxis="scan",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:58:44	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:58:44	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache	START     Current memory usage: 14128.5 kilobytes.
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache	Data Averaging:
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache+	 Using VECTOR averaging.
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache+	 Time: 3300 seconds.  Scan: false;  Field: false
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache+	 All Baselines: true
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache	Caching for the new plot: Phase(18):corrected vs. Channel(5)...
# <br>2020-03-24 15:58:45	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache	Data selection will yield a total of 189000 plottable points (flagged and unflagged).
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.00118944 GB of memory (6.29333 bytes/point).
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache+	This is 0.00729164% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache	Loading chunks with averaging.....
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache+	Channel: 0 to 899 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache+	Phase:corrected: -179.63 to 179.776 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:46	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:58:44	INFO	PlotMS::load_cache	END       Time: +2 seconds.  Memory: +362.812 kilobytes.
# <br>2020-03-24 15:58:46	INFO	PlotMS::plot	Plotting 9000 unflagged points.
# <br>2020-03-24 15:58:46	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:47	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:58:47	INFO	QPExporter::export	START     Current memory usage: 14633.9 kilobytes.
# <br>2020-03-24 15:58:47	INFO	QPExporter::export	END       Time: +0 seconds.  Memory: +1.92188 kilobytes.
# <br>2020-03-24 15:58:47	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:47	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:58:47	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile,
       xaxis='channel',
       yaxis='amp',
       ydatacolumn='corrected',
       correlation='XX,YY',
       field=target,
       coloraxis='corr',
       averagedata=True,
       avgtime='3300',
       avgbaseline=True)
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065529_64" data-target="#log1585065529_64" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065529_64">2020-03-24 15:58:47	INFO	plotms::::
# <br>2020-03-24 15:58:47	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:58:47	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:58:47	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        plotindex=0,xaxis="channel",xdatacolumn="",xframe="",xinterp="",
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        yaxis="amp",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        selectdata=True,field="NGC3621",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        avgtime="3300",avgscan=False,avgfield=False,avgbaseline=True,avgantenna=False,
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        symboloutline=False,coloraxis="corr",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:58:47	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:58:47	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache	START     Current memory usage: 14340.9 kilobytes.
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache	Data Averaging:
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache+	 Using VECTOR averaging.
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache+	 Time: 3300 seconds.  Scan: false;  Field: false
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache+	 All Baselines: true
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):corrected vs. Channel(5)...
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:58:48	INFO	PlotMS::load_cache	Data selection will yield a total of 189000 plottable points (flagged and unflagged).
# <br>2020-03-24 15:58:48	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.00118944 GB of memory (6.29333 bytes/point).
# <br>2020-03-24 15:58:48	INFO	PlotMS::load_cache+	This is 0.00729164% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:58:48	INFO	PlotMS::load_cache	Loading chunks with averaging.....
# <br>2020-03-24 15:58:49	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:58:49	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:58:49	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:58:49	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:58:49	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:58:49	INFO	PlotMS::load_cache+	Channel: 0 to 899 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:49	INFO	PlotMS::load_cache+	Amp:corrected: 0.00194819 to 0.676012 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:49	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:58:47	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +364.219 kilobytes.
# <br>2020-03-24 15:58:49	INFO	PlotMS::plot	Plotting 9000 unflagged points.
# <br>2020-03-24 15:58:49	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:49	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:58:49	INFO	QPExporter::export	START     Current memory usage: 14846.7 kilobytes.
# <br>2020-03-24 15:58:49	INFO	QPExporter::export	END       Time: +0 seconds.  Memory: +1.89062 kilobytes.
# <br>2020-03-24 15:58:50	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:50	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:58:50	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile,
       xaxis='time',
       yaxis='amp',
       ydatacolumn='corrected',
       correlation='XX,YY',
       field=target,
       coloraxis='corr',
       averagedata=True,
       avgbaseline=True,
       avgchannel='4096')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065531_56" data-target="#log1585065531_56" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065531_56">2020-03-24 15:58:50	INFO	plotms::::
# <br>2020-03-24 15:58:50	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:58:50	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:58:50	INFO	plotms::::	plotms(vis="ngc3621_fixvis.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        plotindex=0,xaxis="time",xdatacolumn="",xframe="",xinterp="",
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        yaxis="amp",ydatacolumn="corrected",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        selectdata=True,field="NGC3621",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="4096",
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=True,avgantenna=False,
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        symboloutline=False,coloraxis="corr",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:58:50	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:58:50	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache	START     Current memory usage: 14554.5 kilobytes.
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache	Data Averaging:
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	 Using VECTOR averaging.
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	 Channel: 4096 channels
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	 All Baselines: true
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):corrected vs. Time(2)...
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache	Data selection will yield a total of 18900 plottable points (flagged and unflagged).
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0002484 GB of memory (13.1429 bytes/point).
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache+	This is 0.00152277% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache	Loading chunks with averaging.....
# <br>2020-03-24 15:58:51	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:58:51	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:58:51	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:58:51	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:58:51	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:58:51	INFO	PlotMS::load_cache+	Time: 4.99838e+09 to 4.99838e+09 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:51	INFO	PlotMS::load_cache+	Amp:corrected: 0.012944 to 0.157378 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:51	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:58:50	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +11952.5 kilobytes.
# <br>2020-03-24 15:58:51	INFO	PlotMS::plot	Plotting 900 unflagged points.
# <br>2020-03-24 15:58:51	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:51	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:58:51	INFO	QPExporter::export	START     Current memory usage: 26650.4 kilobytes.
# <br>2020-03-24 15:58:51	INFO	QPExporter::export	END       Time: +0 seconds.  Memory: +1.79688 kilobytes.
# <br>2020-03-24 15:58:52	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:52	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:58:52	INFO	plotms::::+	##########################################
# </div>

# %%
splitted_ms = prefix+'_split.ms'
split(vis=msfile,
      field=target,
      outputvis=splitted_ms,
      datacolumn='corrected')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065532_64" data-target="#log1585065532_64" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065532_64">2020-03-24 15:58:52	INFO	split::::
# <br>2020-03-24 15:58:52	INFO	split::::+	##########################################
# <br>2020-03-24 15:58:52	INFO	split::::+	##### Begin Task: split              #####
# <br>2020-03-24 15:58:52	INFO	split::::	split(vis="ngc3621_fixvis.ms",outputvis="ngc3621_fixvis_split.ms",keepmms=True,field="NGC3621",spw="",
# <br>2020-03-24 15:58:52	INFO	split::::+	        scan="",antenna="",correlation="",timerange="",intent="",
# <br>2020-03-24 15:58:52	INFO	split::::+	        array="",uvrange="",observation="",feed="",datacolumn="corrected",
# <br>2020-03-24 15:58:52	INFO	split::::+	        keepflags=True,width=1,timebin="0s",combine="")
# <br>2020-03-24 15:58:52	INFO	MSTransformManager::parseMsSpecParams	Input file name is ngc3621_fixvis.ms
# <br>2020-03-24 15:58:52	INFO	MSTransformManager::parseMsSpecParams	Data column is CORRECTED
# <br>2020-03-24 15:58:52	INFO	MSTransformManager::parseMsSpecParams	Output file name is ngc3621_fixvis_split.ms
# <br>2020-03-24 15:58:52	INFO	MSTransformManager::parseDataSelParams	field selection is NGC3621
# <br>2020-03-24 15:58:52	INFO	MSTransformManager::colCheckInfo	Adding DATA column to output MS from input CORRECTED_DATA column
# <br>2020-03-24 15:58:52	INFO	MSTransformManager::initDataSelectionParams	Selected Fields Ids are [1]
# <br>2020-03-24 15:58:52	INFO	MSTransformManager::open	Select data
# <br>2020-03-24 15:58:52	INFO	MSTransformManager::createOutputMSStructure	Create output MS structure
# <br>2020-03-24 15:58:52	INFO	MSTransformDataHandler::makeSelection	9450 out of 15687 rows are going to be considered due to the selection criteria.
# <br>2020-03-24 15:58:53	INFO	split::::	CASA Version 5.5.0-149
# <br>2020-03-24 15:58:53	INFO	split::::
# <br>2020-03-24 15:58:53	INFO	split::::	##### End Task: split                #####
# <br>2020-03-24 15:58:53	INFO	split::::+	##########################################
# </div>

# %%
visstat(splitted_ms, axis='amp', field=target)
# Out:
# {'DATA_DESC_ID=0': {'firstquartile': 1.20348060131073,
#   'isMasked': True,
#   'isWeighted': False,
#   'max': 13.495564460754395,
#   'maxDatasetIndex': 290,
#   'maxIndex': 23207,
#   'mean': 2.0246555491808764,
#   'medabsdevmed': 0.7301372289657593,
#   'median': 1.8793160915374756,
#   'min': 0.0004453446890693158,
#   'minDatasetIndex': 332,
#   'minIndex': 10928,
#   'npts': 8100000.0,
#   'rms': 2.3023472527492173,
#   'stddev': 1.0961628199102529,
#   'sum': 16399709.948364627,
#   'sumOfWeights': 8100000.0,
#   'sumsq': 42936503.26515913,
#   'thirdquartile': 2.6843225955963135,
#   'variance': 1.2015729277535974}}
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065534_54" data-target="#log1585065534_54" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065534_54">2020-03-24 15:58:53	INFO	visstat::::
# <br>2020-03-24 15:58:53	INFO	visstat::::+	##########################################
# <br>2020-03-24 15:58:53	INFO	visstat::::+	##### Begin Task: visstat            #####
# <br>2020-03-24 15:58:53	INFO	visstat::::	visstat(vis="ngc3621_fixvis_split.ms",axis="amp",datacolumn="data",useflags=True,spw="",
# <br>2020-03-24 15:58:53	INFO	visstat::::+	        field="NGC3621",selectdata=True,antenna="",uvrange="",timerange="",
# <br>2020-03-24 15:58:53	INFO	visstat::::+	        correlation="",scan="",array="",observation="",timeaverage=False,
# <br>2020-03-24 15:58:53	INFO	visstat::::+	        timebin="0s",timespan="",maxuvwdistance=0.0,disableparallel=False,ddistart=-1,
# <br>2020-03-24 15:58:53	INFO	visstat::::+	        taql="",monolithic_processing=False,intent="",reportingaxes="ddid")
# <br>2020-03-24 15:58:53	INFO	visstat::ms::statistics	Use /home/jupyter/MeerKAT-Cookbook/casa/ngc3621_fixvis_split.ms, useflags = 1, useweights = 0
# <br>2020-03-24 15:58:53	INFO	visstat::ms::statistics	Compute statistics on DATA, use amp...
# <br>2020-03-24 15:58:55	INFO	visstat::::	DATA_DESC_ID=0 values ---
# <br>2020-03-24 15:58:55	INFO	visstat::::	         -- number of points [npts]:           8100000
# <br>2020-03-24 15:58:55	INFO	visstat::::	         -- minimum value [min]:               0.000445344689069
# <br>2020-03-24 15:58:55	INFO	visstat::::	         -- maximum value [max]:               13.4955644608
# <br>2020-03-24 15:58:55	INFO	visstat::::	         -- Sum of values [sum]:               16399709.9484
# <br>2020-03-24 15:58:55	INFO	visstat::::	         -- Sum of squared values [sumsq]:     42936503.2652
# <br>2020-03-24 15:58:55	INFO	visstat::::	DATA_DESC_ID=0 statistics ---
# <br>2020-03-24 15:58:55	INFO	visstat::::	        -- Mean of the values [mean]:                 2.02465554918
# <br>2020-03-24 15:58:55	INFO	visstat::::	        -- Variance of the values [variance]:         1.20157292775
# <br>2020-03-24 15:58:55	INFO	visstat::::	        -- Standard deviation of the values [stddev]: 1.09616281991
# <br>2020-03-24 15:58:55	INFO	visstat::::	        -- Root mean square [rms]:                    2.30234725275
# <br>2020-03-24 15:58:55	INFO	visstat::::	        -- Median of the pixel values [median]:       1.87931609154
# <br>2020-03-24 15:58:55	INFO	visstat::::	        -- Median of the deviations [medabsdevmed]:   0.730137228966
# <br>2020-03-24 15:58:55	INFO	visstat::::	        -- First quartile [firstquartile]:            1.20348060131
# <br>2020-03-24 15:58:55	INFO	visstat::::	        -- Third quartile [thirdquartile]:            2.6843225956
# <br>2020-03-24 15:58:55	INFO	visstat::::	##### End Task: visstat              #####
# <br>2020-03-24 15:58:55	INFO	visstat::::+	##########################################
# </div>

# %%
plotms(vis=splitted_ms,
       xaxis='time',
       yaxis='amp',
       correlation='XX,YY',
       coloraxis='corr',
       averagedata=True,
       avgbaseline=True,
       avgchannel='4096')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065536_59" data-target="#log1585065536_59" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065536_59">2020-03-24 15:58:55	INFO	plotms::::
# <br>2020-03-24 15:58:55	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:58:55	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:58:55	INFO	plotms::::	plotms(vis="ngc3621_fixvis_split.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        plotindex=0,xaxis="time",xdatacolumn="",xframe="",xinterp="",
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        yaxis="amp",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        selectdata=True,field="",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="4096",
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=True,avgantenna=False,
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        symboloutline=False,coloraxis="corr",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:58:55	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:58:55	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache	START     Current memory usage: 22863.5 kilobytes.
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache	Data Averaging:
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	 Using VECTOR averaging.
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	 Channel: 4096 channels
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	 All Baselines: true
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):data vs. Time(2)...
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache	Data selection will yield a total of 18900 plottable points (flagged and unflagged).
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0002484 GB of memory (13.1429 bytes/point).
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache+	This is 0.00152277% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache	Loading chunks with averaging.....
# <br>2020-03-24 15:58:56	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:58:56	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:58:56	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:58:56	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:58:56	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:58:56	INFO	PlotMS::load_cache+	Time: 4.99838e+09 to 4.99838e+09 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:56	INFO	PlotMS::load_cache+	Amp:data: 0.012944 to 0.157378 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:56	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:58:55	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +11922.9 kilobytes.
# <br>2020-03-24 15:58:56	INFO	PlotMS::plot	Plotting 900 unflagged points.
# <br>2020-03-24 15:58:56	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:56	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:58:57	INFO	QPExporter::export	START     Current memory usage: 34927.2 kilobytes.
# <br>2020-03-24 15:58:57	INFO	QPExporter::export	END       Time: +0 seconds.  Memory: +1.75 kilobytes.
# <br>2020-03-24 15:58:57	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:57	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:58:57	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=splitted_ms,
       xaxis='freq',
       yaxis='amp',
       correlation='XX,YY',
       coloraxis='corr',
       averagedata=True,
       avgtime='3300',
       avgbaseline=True)
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1585065539_27" data-target="#log1585065539_27" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1585065539_27">2020-03-24 15:58:57	INFO	plotms::::
# <br>2020-03-24 15:58:57	INFO	plotms::::+	##########################################
# <br>2020-03-24 15:58:57	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-03-24 15:58:57	INFO	plotms::::	plotms(vis="ngc3621_fixvis_split.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        plotindex=0,xaxis="freq",xdatacolumn="",xframe="",xinterp="",
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        yaxis="amp",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        selectdata=True,field="",spw="",timerange="",uvrange="",
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        antenna="",scan="",correlation="XX,YY",array="",observation="",
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        avgtime="3300",avgscan=False,avgfield=False,avgbaseline=True,avgantenna=False,
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        symboloutline=False,coloraxis="corr",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-03-24 15:58:57	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2020-03-24 15:58:57	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache	START     Current memory usage: 31139.7 kilobytes.
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache+	 Frame      =
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache	Data Averaging:
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache+	 Using VECTOR averaging.
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache+	 Time: 3300 seconds.  Scan: false;  Field: false
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache+	 All Baselines: true
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):data vs. Frequency(6)...
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-03-24 15:58:58	INFO	PlotMS::load_cache	Data selection will yield a total of 189000 plottable points (flagged and unflagged).
# <br>2020-03-24 15:58:58	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.00118944 GB of memory (6.29333 bytes/point).
# <br>2020-03-24 15:58:58	INFO	PlotMS::load_cache+	This is 0.00729164% of the memory avail. to CASA (16.3124 GB).
# <br>2020-03-24 15:58:58	INFO	PlotMS::load_cache	Loading chunks with averaging.....
# <br>2020-03-24 15:58:59	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2020-03-24 15:58:59	INFO	PlotMS::load_cache	refTime = 2017/04/08/00:00:00.0
# <br>2020-03-24 15:58:59	INFO	PlotMS::load_cache	Finished loading.
# <br>2020-03-24 15:58:59	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2020-03-24 15:58:59	INFO	PlotMS::load_cache	Axes ranges:
# <br>2020-03-24 15:58:59	INFO	PlotMS::load_cache+	Frequency: 1.39936 to 1.42284 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:59	INFO	PlotMS::load_cache+	Amp:data: 0.00194819 to 0.676012 (unflagged); (no flagged data)
# <br>2020-03-24 15:58:59	INFO	PlotMS::load_cache	Finished indexing.
# <br>2020-03-24 15:58:57	INFO	PlotMS::load_cache	END       Time: +2 seconds.  Memory: +363.578 kilobytes.
# <br>2020-03-24 15:58:59	INFO	PlotMS::plot	Plotting 9000 unflagged points.
# <br>2020-03-24 15:58:59	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:59	INFO	plotms::::	Exporting the plot.
# <br>2020-03-24 15:58:59	INFO	QPExporter::export	START     Current memory usage: 31643.2 kilobytes.
# <br>2020-03-24 15:58:59	INFO	QPExporter::export	END       Time: +0 seconds.  Memory: +1.79688 kilobytes.
# <br>2020-03-24 15:58:59	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/casa/plotms_temp.png
# <br>2020-03-24 15:58:59	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-03-24 15:58:59	INFO	plotms::::+	##########################################
# </div>
