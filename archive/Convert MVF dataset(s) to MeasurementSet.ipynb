# %% [markdown]
# ## Convert MVF dataset(s) to MeasurementSet
# Converting the MeerKAT MVF observation data to a CASA measurement set is done using the `mvftoms.py` script provided with the `katdal` package installation.
#
# `Usage: mvftoms.py [options] <dataset> [<dataset2>]*`
#
# For detail help: `mvftoms.py -h`

# %% [markdown]
# ### Options
# Options when converting MVF to MeasurementSet
# <table>
#     <thead>
#         <tr>
#             <th>Option</th>
#             <th>Value</th>
#             <th><p align="left">Description</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>-o</td>
#             <td>OUTPUT_MS</td>
#             <td><p align="left">Output Measurement Set</td>
#         </tr>
#         <tr>
#             <td>-r</td>
#             <td>REF_ANT</td>
#             <td><p align="left">Reference antenna. <strong>Default is first antenna used by script</strong></td>
#         </tr>
#         <tr>
#             <td>-t</td>
#             <td></td>
#             <td><p align="left">Tar-ball the MS</td>
#         </tr>
#         <tr>
#             <td>-f</td>
#             <td></td>
#             <td><p align="left">Produce a full polarisation MS in CASA canonical order (HH, HV, VH, VV). <strong>Default is to produce HH,VV only</strong></td>
#         </tr>
#         <tr>
#             <td>-v</td>
#             <td></td>
#             <td><p align="left">More verbose progress information</td>
#         </tr>
#         <tr>
#             <td>-w</td>
#             <td></td>
#             <td><p align="left">Use W term to stop fringes for each baseline</td>
#         </tr>
#         <tr>
#             <td>-p</td>
#             <td></td>
#             <td><p align="left">Select polarisation products to include in MS as comma separated list (from: HH, HV, VH, VV). <strong>Default is all available from HH, VV</strong></td>
#         </tr>
#         <tr>
#             <td>-a</td>
#             <td></td>
#             <td><p align="left">MeasurementSet will exclude autocorrelation data</td>
#         </tr>
#         <tr>
#             <td>-s</td>
#             <td></td>
#             <td><p align="left">Keep spaces in source names, default removes spaces</td>
#         </tr>
#         <tr>
#             <td>-C</td>
#             <td>CHANNEL_RANGE</td>
#             <td><p align="left">Range of frequency channels to keep (zero-based inclusive 'first_chan,last_chan', <strong>default is all channels</strong>)</td>
#         </tr>
#         <tr>
#             <td>-e</td>
#             <td>ELEVATION_RANGE</td>
#             <td><p align="left">Flag elevations outside the range 'lowest_elevation,highest_elevation'</td>
#         </tr>
#         <tr>
#             <td>-m</td>
#             <td></td>
#             <td><p align="left">Add MODEL_DATA and CORRECTED_DATA columns to the MS. MODEL_DATA initialised to unity amplitude zero phase, CORRECTED_DATA initialised to DATA</td>
#         </tr>
#         <tr>
#             <td>--flags</td>
#             <td>FLAGS</td>
#             <td><p align="left">List of online flags to apply (from 'static,cam,data_lost,ingest_rfi,cal_rfi,predicted_rfi', <strong>default is all flags</strong>, '' will apply no flags)</td>
#         </tr>
#         <tr>
#             <td width="10%">--dumptime</td>
#             <td>DUMPTIME</td>
#             <td><p align="left">Output time averaging interval in seconds, <strong>default is no averaging</strong></td>
#         </tr>
#         <tr>
#             <td>--chanbin</td>
#             <td>CHANBIN</td>
#             <td><p align="left">Bin width for channel averaging in channels, <strong>default is no averaging</strong></td>
#         </tr>
#         <tr>
#             <td>--flagav</td>
#             <td></td>
#             <td><p align="left">Create calibration tables from gain solutions in the dataset, if present</td>
#         </tr>
#         <tr>
#             <td>--caltables</td>
#             <td></td>
#             <td><p align="left">If a single element in an averaging bin is flagged, flag the averaged bin</td>
#         </tr>
#         <tr>
#             <td>--quack</td>
#             <td>N</td>
#             <td><p align="left">Discard the first N dumps (which are frequently incomplete)</td>
#         </tr>
#         <tr>
#             <td>--applycal</td>
#             <td>APPLYCAL</td>
#             <td><p align="left">List of calibration solutions to apply to data as a string of comma-separated names, e.g. 'l1' or 'K,B,G'. <strong>Use 'default' for L1 + L2 and 'all' for all available products.</strong></td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### Filename
# The `<filename>` provided to `katdal` has to include the complete web path the data in the MeerKAT archive, as well as a valid token, in the format:
# captureblockID
#
# ```
# mvftoms.py [options] https://archive-gw-1.kat.ac.za/<captureblockID>/<captureblockID>_sdp_l0.full.rdb?token=<tokenString>
# ```

# %% [markdown]
# ## Example 1
# Convert the full observation to an output MS, and use the `-o` option to specify an appropriate name for the output Measurement Set
# ```
# mvftoms.py https://archive-gw-1.kat.ac.za/1548417874/1548417874_sdp_l0.full.rdb?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJpc3MiOiJrYXQtYXJjaGl2ZS5rYXQuYWMuemEiLCJhdWQiOiJhcmNoaXZlLWd3LTEua2F0LmFjLnphIiwiaWF0IjoxNTcxMjA5MTI2LCJwcmVmaXgiOlsiMTU0ODQxNzg3NCJdLCJleHAiOjE1NzE4MTM5MjYsInN1YiI6ImRldiIsInNjb3BlcyI6WyJyZWFkIl19.2FXdpi0IPYegu3Dvw9DRJitIT7KU3ZpL7jXqPW0kFM9mGHiFLHi10hfBi2uoP1cjNNw92g6ht1PEsELlYK_Gxw -o exms_full.ms
# ```
#
# Default behaviour that should be noted:
# * If a reference antenna is not specified, the first antenna used will be selected by default
# * Since full polarisation was not specified, only HH, VV products will be produced
# * All flags to remove suspected bad data are applied by default. Flagging during conversion is by no means exhaustive and some flagging will still be required in CASA during data processing.
# **Note: pre-flagging is generally good for continuum imaging, care should be taken for spectral lines, since it may flag out science lines.**

# %% [markdown]
# For older files you may encounder the following error:
# ```
# katsdptelstate.errors.DecodeError: The telescope state contains pickled values. This is a security risk, so is disabled by default. If you trust the source of the data, you can allow the pickles to be loaded by setting KATSDPTELSTATE_ALLOW_PICKLE=1 in the environment. This is needed for MeerKAT data up to March 2019.
# ```
#
# To fix this:
# ```
# export KATSDPTELSTATE_ALLOW_PICKLE=1
# ```
#
# Refer to https://pypi.org/project/katsdptelstate/ for more information

# %%
msfile = 'exms_full.ms'
target = 'PKS1934-63'
listobs(vis=msfile)
# Out:
# ================================================================================
#            MeasurementSet Name:  /home/jupyter/MeerKAT-Cookbook/utils/exms_full.ms      MS Version 2
# ================================================================================
#    Observer: Lindsay     Project: 20190125-0012
# Observation: MeerKAT
# Data records: 240       Total elapsed time = 191.919 seconds
#    Observed from   25-Jan-2019/12:05:08.4   to   25-Jan-2019/12:08:20.3 (UTC)
#
#    ObservationID = 0         ArrayID = 0
#   Date        Timerange (UTC)          Scan  FldId FieldName             nRows     SpwIds   Average Interval(s)    ScanIntent
#   25-Jan-2019/12:05:08.4 - 12:08:20.3     1      0 PKS1934-63                 240  [0]  [8] [UNKNOWN]
#            (nRows = Total number of rows per scan)
# Fields: 1
#   ID   Code Name                RA               Decl           Epoch   SrcId      nRows
#   0    T    PKS1934-63          19:39:25.030000 -63.42.45.70000 J2000   0            240
# Spectral Windows:  (1 unique spectral windows and 1 unique polarization setups)
#   SpwID  Name   #Chans   Frame   Ch0(MHz)  ChanWid(kHz)  TotBW(kHz) CtrFreq(MHz)  Corrs
#   0      none    4096   TOPO     856.000       208.984    856000.0   1283.8955   XX  YY
# Sources: 1
#   ID   Name                SpwId RestFreq(MHz)
#   0    PKS1934-63          0     -
#   NB: No systemic velocity information found in SOURCE table.
# Antennas: 4:
#   ID   Name  Station   Diam.    Long.         Lat.                Offset from array center (m)                ITRF Geocentric coordinates (m)
#                                                                      East         North     Elevation               x               y               z
#   0    m010  m010      13.5 m   +021.26.41.3  -30.32.49.1         87.0329     -274.0563      -12.0002  5109046.342503  2006823.982229 -3239363.792060
#   1    m043  m043      13.5 m   +021.26.14.3  -30.32.36.7       -630.9123      109.5241      -16.7813  5109486.398942  2006225.484528 -3239031.012788
#   2    m053  m053      13.5 m   +021.26.38.4  -30.33.14.8          8.3009    -1066.6557      -10.3748  5108701.441647  2006603.926330 -3240047.188721
#   3    m054  m054      13.5 m   +021.27.10.8  -30.32.48.7        870.9375     -261.9677       -9.7286  5108767.237976  2007556.539449 -3239354.535754
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268348_05" data-target="#log1571268348_05" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268348_05">2019-10-16 23:25:48	INFO	listobs::::
# <br>2019-10-16 23:25:48	INFO	listobs::::+	##########################################
# <br>2019-10-16 23:25:48	INFO	listobs::::+	##### Begin Task: listobs            #####
# <br>2019-10-16 23:25:48	INFO	listobs::::	listobs(vis="exms_full.ms",selectdata=True,spw="",field="",antenna="",
# <br>2019-10-16 23:25:48	INFO	listobs::::+	        uvrange="",timerange="",correlation="",scan="",intent="",
# <br>2019-10-16 23:25:48	INFO	listobs::::+	        feed="",array="",observation="",verbose=True,listfile="casapy_temp.txt",
# <br>2019-10-16 23:25:48	INFO	listobs::::+	        listunfl=False,cachesize=50,overwrite=True)
# <br>2019-10-16 23:25:48	INFO	listobs::ms::summary	Writing output to file: casapy_temp.txt
# <br>2019-10-16 23:25:48	INFO	listobs::MSMetaData::_computeScanAndSubScanProperties 	Computing scan and subscan properties...
# <br>2019-10-16 23:25:48	INFO	listobs::::	##### End Task: listobs              #####
# <br>2019-10-16 23:25:48	INFO	listobs::::+	##########################################
# </div>

# %%
plotms(vis=msfile, xaxis='freq', yaxis='amp', field=target, coloraxis='baseline', antenna='*&')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268354_11" data-target="#log1571268354_11" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268354_11">2019-10-16 23:25:48	INFO	plotms::::
# <br>2019-10-16 23:25:48	INFO	plotms::::+	##########################################
# <br>2019-10-16 23:25:48	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2019-10-16 23:25:48	INFO	plotms::::	plotms(vis="exms_full.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        plotindex=0,xaxis="freq",xdatacolumn="",xframe="",xinterp="",
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        yaxis="amp",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        selectdata=True,field="PKS1934-63",spw="",timerange="",uvrange="",
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        antenna="*&",scan="",correlation="",array="",observation="",
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        symboloutline=False,coloraxis="baseline",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2019-10-16 23:25:48	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2019-10-16 23:25:50	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2019-10-16 23:25:50	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache	START     Current memory usage: 2288.19 kilobytes.
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache+	 Frame      =
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):data vs. Frequency(6)...
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache	Loading page header cache
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache	Data selection will yield a total of 1179648 plottable points (flagged and unflagged).
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.00826013 GB of memory (7.0022 bytes/point).
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache+	This is 0.0506351% of the memory avail. to CASA (16.3131 GB).
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache	Loading chunks......
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache	refTime = 2019/01/25/00:00:00.0
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache	Finished loading.
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache	Axes ranges:
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache+	Frequency: 0.856209 to 1.71179 (unflagged); ; 0.856 to 1.71179 (flagged).
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache+	Amp:data: 0 to 11.1707 (unflagged); 0 to 11908.4(flagged).
# <br>2019-10-16 23:25:51	INFO	PlotMS::load_cache	Finished indexing.
# <br>2019-10-16 23:25:50	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +9427.44 kilobytes.
# <br>2019-10-16 23:25:51	INFO	PlotMS::plot	Plotting 768688 unflagged points.
# <br>2019-10-16 23:25:51	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:25:52	INFO	plotms::::	Exporting the plot.
# <br>2019-10-16 23:25:52	INFO	QPExporter::export	START     Current memory usage: 12175 kilobytes.
# <br>2019-10-16 23:25:52	INFO	QPExporter::export	END       Time: +3 seconds.  Memory: +44.9375 kilobytes.
# <br>2019-10-16 23:25:54	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:25:54	INFO	plotms::::	##### End Task: plotms               #####
# <br>2019-10-16 23:25:54	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile, xaxis='freq', yaxis='amp', field=target, coloraxis='baseline', antenna='*&&&')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268361_83" data-target="#log1571268361_83" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268361_83">2019-10-16 23:25:54	INFO	plotms::::
# <br>2019-10-16 23:25:54	INFO	plotms::::+	##########################################
# <br>2019-10-16 23:25:54	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2019-10-16 23:25:54	INFO	plotms::::	plotms(vis="exms_full.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        plotindex=0,xaxis="freq",xdatacolumn="",xframe="",xinterp="",
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        yaxis="amp",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        selectdata=True,field="PKS1934-63",spw="",timerange="",uvrange="",
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        antenna="*&&&",scan="",correlation="",array="",observation="",
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        symboloutline=False,coloraxis="baseline",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2019-10-16 23:25:54	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2019-10-16 23:25:56	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache	START     Current memory usage: 5612.08 kilobytes.
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache+	 Frame      =
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):data vs. Frequency(6)...
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache	Loading page header cache
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache	Data selection will yield a total of 786432 plottable points (flagged and unflagged).
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.00590026 GB of memory (7.50256 bytes/point).
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache+	This is 0.0361689% of the memory avail. to CASA (16.3131 GB).
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache	Loading chunks......
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache	refTime = 2019/01/25/00:00:00.0
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache	Finished loading.
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache	Axes ranges:
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache+	Frequency: 0.856209 to 1.71179 (unflagged); ; 0.856 to 1.68755 (flagged).
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache+	Amp:data: 0 to 2090.13 (unflagged); 0 to 10280.2(flagged).
# <br>2019-10-16 23:25:57	INFO	PlotMS::load_cache	Finished indexing.
# <br>2019-10-16 23:25:56	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +5904.38 kilobytes.
# <br>2019-10-16 23:25:57	INFO	PlotMS::plot	Plotting 766899 unflagged points.
# <br>2019-10-16 23:25:57	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:25:59	INFO	plotms::::	Exporting the plot.
# <br>2019-10-16 23:25:59	INFO	QPExporter::export	START     Current memory usage: 11653.5 kilobytes.
# <br>2019-10-16 23:25:59	INFO	QPExporter::export	END       Time: +2 seconds.  Memory: +2.0625 kilobytes.
# <br>2019-10-16 23:26:02	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:26:02	INFO	plotms::::	##### End Task: plotms               #####
# <br>2019-10-16 23:26:02	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile, xaxis='freq', yaxis='phase', field=target, coloraxis='baseline')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268368_23" data-target="#log1571268368_23" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268368_23">2019-10-16 23:26:02	INFO	plotms::::
# <br>2019-10-16 23:26:02	INFO	plotms::::+	##########################################
# <br>2019-10-16 23:26:02	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2019-10-16 23:26:02	INFO	plotms::::	plotms(vis="exms_full.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        plotindex=0,xaxis="freq",xdatacolumn="",xframe="",xinterp="",
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        yaxis="phase",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        selectdata=True,field="PKS1934-63",spw="",timerange="",uvrange="",
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        antenna="",scan="",correlation="",array="",observation="",
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        symboloutline=False,coloraxis="baseline",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2019-10-16 23:26:02	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2019-10-16 23:26:04	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache	START     Current memory usage: 5630.31 kilobytes.
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache+	 Frame      =
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache	Caching for the new plot: Phase(18):data vs. Frequency(6)...
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache	Loading page header cache
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache	Data selection will yield a total of 1966080 plottable points (flagged and unflagged).
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0129799 GB of memory (6.6019 bytes/point).
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache+	This is 0.0795674% of the memory avail. to CASA (16.3131 GB).
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache	Loading chunks......
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache	refTime = 2019/01/25/00:00:00.0
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache	Finished loading.
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache	Axes ranges:
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache+	Frequency: 0.856209 to 1.71179 (unflagged); ; 0.856 to 1.71179 (flagged).
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache+	Phase:data: -180 to 179.999 (unflagged); -179.999 to 180(flagged).
# <br>2019-10-16 23:26:05	INFO	PlotMS::load_cache	Finished indexing.
# <br>2019-10-16 23:26:04	INFO	PlotMS::load_cache	END       Time: +0 seconds.  Memory: +12817 kilobytes.
# <br>2019-10-16 23:26:05	INFO	PlotMS::plot	Plotting 1535587 unflagged points.
# <br>2019-10-16 23:26:05	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:26:07	INFO	plotms::::	Exporting the plot.
# <br>2019-10-16 23:26:07	INFO	QPExporter::export	START     Current memory usage: 18589.7 kilobytes.
# <br>2019-10-16 23:26:07	INFO	QPExporter::export	END       Time: +2 seconds.  Memory: +1.40625 kilobytes.
# <br>2019-10-16 23:26:08	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:26:08	INFO	plotms::::	##### End Task: plotms               #####
# <br>2019-10-16 23:26:08	INFO	plotms::::+	##########################################
# </div>

# %% [markdown]
# ## Example 2
#
# Selection of options based on information shown in observation [calibration report](https://github.com/ska-sa/MeerKAT-Cookbook/blob/master/archive/Calibration%20pipeline%20report.pdf)
#
# Convert only the channels defining the passband and exclude the transition band channels from the output MS
# ```
# mvftoms.py https://archive-gw-1.kat.ac.za/1557528200/1557528200_sdp_l0.full.rdb?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJpc3MiOiJrYXQtYXJjaGl2ZS5rYXQuYWMuemEiLCJhdWQiOiJhcmNoaXZlLWd3LTEua2F0LmFjLnphIiwiaWF0IjoxNTY2MzAyNTc0LCJwcmVmaXgiOlsiMTU0ODQxNzg3NCJdLCJleHAiOjE1NjYzODg5NzQsInN1YiI6ImRldiIsInNjb3BlcyI6WyJyZWFkIl19.rfFOiJSjE2F3XzngTHsFvmUGNpVxwXnUxoksNSubkbF9okItafl3ooLAdNQ6xQEzasn826XItMwTaHVQqj4eYA -o exms_passband.ms -f -a -C '163,3885' -r 'm053' --flags 'static,cam,data_lost,ingest_rfi' --quack=3
# ```
#
# Options specified:
# * `-f` produce a full polarisation MS in CASA canonical order (HH, HV, VH, VV)
# * `-a` exclude autocorrelation data
# * `-C` range of frequency channels to keep. Selection is `'163,3885'` which will discard the edges of the band and only use the passband channels during conversion. Refer to the *RFI and Flagging summary* section in the observation calibration report for usable section channels/frequencies
# * `-r` specify a reference antenna selected to be the same reference antenna used in the calibration report
# * `--flags` remove selection of non-usable data and RFI, good default selection `'static,cam,data_lost,ingest_rfi'`
# * `--quack` discard the first N dumps. Refer to the observation summary in the *Description* provided by the MeerKAT archive interface

# %% [markdown]
# Smaller example showing similar results
# ```
# mvftoms.py https://archive-gw-1.kat.ac.za/1548417874/1548417874_sdp_l0.full.rdb?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJpc3MiOiJrYXQtYXJjaGl2ZS5rYXQuYWMuemEiLCJhdWQiOiJhcmNoaXZlLWd3LTEua2F0LmFjLnphIiwiaWF0IjoxNTcxMjA5MTI2LCJwcmVmaXgiOlsiMTU0ODQxNzg3NCJdLCJleHAiOjE1NzE4MTM5MjYsInN1YiI6ImRldiIsInNjb3BlcyI6WyJyZWFkIl19.2FXdpi0IPYegu3Dvw9DRJitIT7KU3ZpL7jXqPW0kFM9mGHiFLHi10hfBi2uoP1cjNNw92g6ht1PEsELlYK_Gxw -o exms_passband.ms -f -a -C '163,3885' -r 'm053' --flags 'static,cam,data_lost,ingest_rfi' --quack=3
# ```

# %%
msfile = 'exms_passband.ms'
target = 'PKS1934-63'
listobs(vis=msfile)
# Out:
# ================================================================================
#            MeasurementSet Name:  /home/jupyter/MeerKAT-Cookbook/utils/exms_passband.ms      MS Version 2
# ================================================================================
#    Observer: Lindsay     Project: 20190125-0012
# Observation: MeerKAT
# Data records: 150       Total elapsed time = 199.915 seconds
#    Observed from   25-Jan-2019/12:05:00.4   to   25-Jan-2019/12:08:20.3 (UTC)
#
#    ObservationID = 0         ArrayID = 0
#   Date        Timerange (UTC)          Scan  FldId FieldName             nRows     SpwIds   Average Interval(s)    ScanIntent
#   25-Jan-2019/12:05:00.4 - 12:08:20.3     1      0 PKS1934-63                 150  [0]  [8] [UNKNOWN]
#            (nRows = Total number of rows per scan)
# Fields: 1
#   ID   Code Name                RA               Decl           Epoch   SrcId      nRows
#   0    T    PKS1934-63          19:39:25.030000 -63.42.45.70000 J2000   0            150
# Spectral Windows:  (1 unique spectral windows and 1 unique polarization setups)
#   SpwID  Name   #Chans   Frame   Ch0(MHz)  ChanWid(kHz)  TotBW(kHz) CtrFreq(MHz)  Corrs
#   0      none    3723   TOPO     890.064       208.984    778048.8   1278.9844   XX  XY  YX  YY
# Sources: 1
#   ID   Name                SpwId RestFreq(MHz)
#   0    PKS1934-63          0     -
#   NB: No systemic velocity information found in SOURCE table.
# Antennas: 4:
#   ID   Name  Station   Diam.    Long.         Lat.                Offset from array center (m)                ITRF Geocentric coordinates (m)
#                                                                      East         North     Elevation               x               y               z
#   0    m010  m010      13.5 m   +021.26.41.3  -30.32.49.1         87.0329     -274.0563      -12.0002  5109046.342503  2006823.982229 -3239363.792060
#   1    m043  m043      13.5 m   +021.26.14.3  -30.32.36.7       -630.9123      109.5241      -16.7813  5109486.398942  2006225.484528 -3239031.012788
#   2    m053  m053      13.5 m   +021.26.38.4  -30.33.14.8          8.3009    -1066.6557      -10.3748  5108701.441647  2006603.926330 -3240047.188721
#   3    m054  m054      13.5 m   +021.27.10.8  -30.32.48.7        870.9375     -261.9677       -9.7286  5108767.237976  2007556.539449 -3239354.535754
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268368_3" data-target="#log1571268368_3" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268368_3">2019-10-16 23:26:08	INFO	listobs::::
# <br>2019-10-16 23:26:08	INFO	listobs::::+	##########################################
# <br>2019-10-16 23:26:08	INFO	listobs::::+	##### Begin Task: listobs            #####
# <br>2019-10-16 23:26:08	INFO	listobs::::	listobs(vis="exms_passband.ms",selectdata=True,spw="",field="",antenna="",
# <br>2019-10-16 23:26:08	INFO	listobs::::+	        uvrange="",timerange="",correlation="",scan="",intent="",
# <br>2019-10-16 23:26:08	INFO	listobs::::+	        feed="",array="",observation="",verbose=True,listfile="casapy_temp.txt",
# <br>2019-10-16 23:26:08	INFO	listobs::::+	        listunfl=False,cachesize=50,overwrite=True)
# <br>2019-10-16 23:26:08	INFO	listobs::ms::summary	Writing output to file: casapy_temp.txt
# <br>2019-10-16 23:26:08	INFO	listobs::MSMetaData::_computeScanAndSubScanProperties 	Computing scan and subscan properties...
# <br>2019-10-16 23:26:08	INFO	listobs::::	##### End Task: listobs              #####
# <br>2019-10-16 23:26:08	INFO	listobs::::+	##########################################
# </div>

# %%
plotants(vis=msfile)
# Out:
# Number of points being plotted: 60
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268588_35" data-target="#log1571268588_35" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268588_35">2019-10-16 23:29:48	INFO	plotants::::
# <br>2019-10-16 23:29:48	INFO	plotants::::+	##########################################
# <br>2019-10-16 23:29:48	INFO	plotants::::+	##### Begin Task: plotants           #####
# <br>2019-10-16 23:29:48	INFO	plotants::::	plotants(vis="1557528200.ms",figfile="",antindex=False,logpos=False,exclude="",
# <br>2019-10-16 23:29:48	INFO	plotants::::+	        checkbaselines=False,title="",showgui=True)
# <br>2019-10-16 23:29:48	INFO	msmetadata_cmpt.cc::open	Performing internal consistency checks on 1557528200.ms...
# <br>2019-10-16 23:29:48	INFO	plotants::::	Number of points being plotted: 60
# <br>2019-10-16 23:29:48	INFO	plotants::::	##### End Task: plotants             #####
# <br>2019-10-16 23:29:48	INFO	plotants::::+	##########################################
# </div>

# %%
plotms(vis=msfile, xaxis='freq', yaxis='amp', field=target, coloraxis='baseline')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268374_0" data-target="#log1571268374_0" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268374_0">2019-10-16 23:26:09	INFO	plotms::::
# <br>2019-10-16 23:26:09	INFO	plotms::::+	##########################################
# <br>2019-10-16 23:26:09	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2019-10-16 23:26:09	INFO	plotms::::	plotms(vis="exms_passband.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        plotindex=0,xaxis="freq",xdatacolumn="",xframe="",xinterp="",
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        yaxis="amp",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        selectdata=True,field="PKS1934-63",spw="",timerange="",uvrange="",
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        antenna="",scan="",correlation="",array="",observation="",
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        symboloutline=False,coloraxis="baseline",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2019-10-16 23:26:09	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2019-10-16 23:26:10	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache	START     Current memory usage: 5644.59 kilobytes.
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache+	 Frame      =
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):data vs. Frequency(6)...
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache	Loading page header cache
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache	Data selection will yield a total of 2233800 plottable points (flagged and unflagged).
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0145226 GB of memory (6.5013 bytes/point).
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache+	This is 0.0890244% of the memory avail. to CASA (16.3131 GB).
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache	Loading chunks......
# <br>2019-10-16 23:26:11	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2019-10-16 23:26:11	INFO	PlotMS::load_cache	refTime = 2019/01/25/00:00:00.0
# <br>2019-10-16 23:26:11	INFO	PlotMS::load_cache	Finished loading.
# <br>2019-10-16 23:26:11	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2019-10-16 23:26:11	INFO	PlotMS::load_cache	Axes ranges:
# <br>2019-10-16 23:26:11	INFO	PlotMS::load_cache+	Frequency: 0.890064 to 1.6679 (unflagged); ; 0.935414 to 1.62966 (flagged).
# <br>2019-10-16 23:26:11	INFO	PlotMS::load_cache+	Amp:data: 0 to 709.386 (unflagged); 0 to 11908.4(flagged).
# <br>2019-10-16 23:26:11	INFO	PlotMS::load_cache	Finished indexing.
# <br>2019-10-16 23:26:10	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +14325.5 kilobytes.
# <br>2019-10-16 23:26:11	INFO	PlotMS::plot	Plotting 1491616 unflagged points.
# <br>2019-10-16 23:26:11	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:26:12	INFO	plotms::::	Exporting the plot.
# <br>2019-10-16 23:26:12	INFO	QPExporter::export	START     Current memory usage: 20112.6 kilobytes.
# <br>2019-10-16 23:26:12	INFO	QPExporter::export	END       Time: +1 seconds.  Memory: +2.42188 kilobytes.
# <br>2019-10-16 23:26:14	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:26:14	INFO	plotms::::	##### End Task: plotms               #####
# <br>2019-10-16 23:26:14	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile, xaxis='freq', yaxis='phase', field=target, coloraxis='baseline')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268380_06" data-target="#log1571268380_06" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268380_06">2019-10-16 23:26:14	INFO	plotms::::
# <br>2019-10-16 23:26:14	INFO	plotms::::+	##########################################
# <br>2019-10-16 23:26:14	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2019-10-16 23:26:14	INFO	plotms::::	plotms(vis="exms_passband.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        plotindex=0,xaxis="freq",xdatacolumn="",xframe="",xinterp="",
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        yaxis="phase",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        selectdata=True,field="PKS1934-63",spw="",timerange="",uvrange="",
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        antenna="",scan="",correlation="",array="",observation="",
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        symboloutline=False,coloraxis="baseline",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2019-10-16 23:26:14	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2019-10-16 23:26:16	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	START     Current memory usage: 5658.77 kilobytes.
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	 Frame      =
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Caching for the new plot: Phase(18):data vs. Frequency(6)...
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Loading page header cache
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Data selection will yield a total of 2233800 plottable points (flagged and unflagged).
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0145226 GB of memory (6.5013 bytes/point).
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	This is 0.0890244% of the memory avail. to CASA (16.3131 GB).
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Loading chunks......
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	refTime = 2019/01/25/00:00:00.0
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Finished loading.
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Axes ranges:
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	Frequency: 0.890064 to 1.6679 (unflagged); ; 0.935414 to 1.62966 (flagged).
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache+	Phase:data: -179.998 to 180 (unflagged); -179.999 to 180(flagged).
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	Finished indexing.
# <br>2019-10-16 23:26:16	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +14324.5 kilobytes.
# <br>2019-10-16 23:26:16	INFO	PlotMS::plot	Plotting 1491616 unflagged points.
# <br>2019-10-16 23:26:16	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:26:18	INFO	plotms::::	Exporting the plot.
# <br>2019-10-16 23:26:18	INFO	QPExporter::export	START     Current memory usage: 20123.9 kilobytes.
# <br>2019-10-16 23:26:18	INFO	QPExporter::export	END       Time: +2 seconds.  Memory: +1.54688 kilobytes.
# <br>2019-10-16 23:26:20	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:26:20	INFO	plotms::::	##### End Task: plotms               #####
# <br>2019-10-16 23:26:20	INFO	plotms::::+	##########################################
# </div>

# %% [markdown]
# ## Example 3
#
# More selective example
# Only select the frequency range between 1.3 GHz and 1.5 GHz for convertion into MS
# ```
# mvftoms.py https://archive-gw-1.kat.ac.za/1548417874/1548417874_sdp_l0.full.rdb?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJpc3MiOiJrYXQtYXJjaGl2ZS5rYXQuYWMuemEiLCJhdWQiOiJhcmNoaXZlLWd3LTEua2F0LmFjLnphIiwiaWF0IjoxNTcxMjA5MTI2LCJwcmVmaXgiOlsiMTU0ODQxNzg3NCJdLCJleHAiOjE1NzE4MTM5MjYsInN1YiI6ImRldiIsInNjb3BlcyI6WyJyZWFkIl19.2FXdpi0IPYegu3Dvw9DRJitIT7KU3ZpL7jXqPW0kFM9mGHiFLHi10hfBi2uoP1cjNNw92g6ht1PEsELlYK_Gxw -o 1548417874.ms -f -a -C '2150,3150' -r 'm053' --flags 'static,cam,data_lost,ingest_rfi' --quack=1
# ```

# %%
plotms(vis='1548417874.ms', xaxis='chan', yaxis='amp', coloraxis='corr')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268389_39" data-target="#log1571268389_39" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268389_39">2019-10-16 23:26:20	INFO	plotms::::
# <br>2019-10-16 23:26:20	INFO	plotms::::+	##########################################
# <br>2019-10-16 23:26:20	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2019-10-16 23:26:20	INFO	plotms::::	plotms(vis="1548417874.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        plotindex=0,xaxis="chan",xdatacolumn="",xframe="",xinterp="",
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        yaxis="amp",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        selectdata=True,field="",spw="",timerange="",uvrange="",
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        antenna="",scan="",correlation="",array="",observation="",
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        symboloutline=False,coloraxis="corr",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2019-10-16 23:26:20	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2019-10-16 23:26:22	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	START     Current memory usage: 5669.72 kilobytes.
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache+	 Frame      =
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):data vs. Channel(5)...
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	Loading page header cache
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	Data selection will yield a total of 3574080 plottable points (flagged and unflagged).
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0225206 GB of memory (6.3011 bytes/point).
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache+	This is 0.138053% of the memory avail. to CASA (16.3131 GB).
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	Loading chunks......
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	refTime = 2019/01/25/00:00:00.0
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	Finished loading.
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2019-10-16 23:26:23	INFO	PlotMS::load_cache	Axes ranges:
# <br>2019-10-16 23:26:23	INFO	PlotMS::load_cache+	Channel: 0 to 3722 (unflagged); ; 217 to 3539 (flagged).
# <br>2019-10-16 23:26:23	INFO	PlotMS::load_cache+	Amp:data: 0 to 271.671 (unflagged); 0 to 1752.54(flagged).
# <br>2019-10-16 23:26:23	INFO	PlotMS::load_cache	Finished indexing.
# <br>2019-10-16 23:26:22	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +22132.2 kilobytes.
# <br>2019-10-16 23:26:23	INFO	PlotMS::plot	Plotting 2566390 unflagged points.
# <br>2019-10-16 23:26:23	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:26:26	INFO	plotms::::	Exporting the plot.
# <br>2019-10-16 23:26:26	INFO	QPExporter::export	START     Current memory usage: 27944.6 kilobytes.
# <br>2019-10-16 23:26:26	INFO	QPExporter::export	END       Time: +4 seconds.  Memory: +2.01562 kilobytes.
# <br>2019-10-16 23:26:29	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:26:29	INFO	plotms::::	##### End Task: plotms               #####
# <br>2019-10-16 23:26:29	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis='1548417874.ms', xaxis='freq', yaxis='amp', coloraxis='corr')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268400_41" data-target="#log1571268400_41" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268400_41">2019-10-16 23:26:30	INFO	plotms::::
# <br>2019-10-16 23:26:30	INFO	plotms::::+	##########################################
# <br>2019-10-16 23:26:30	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2019-10-16 23:26:30	INFO	plotms::::	plotms(vis="1548417874.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        plotindex=0,xaxis="freq",xdatacolumn="",xframe="",xinterp="",
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        yaxis="amp",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        selectdata=True,field="",spw="",timerange="",uvrange="",
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        antenna="",scan="",correlation="",array="",observation="",
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        avgtime="",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        symboloutline=False,coloraxis="corr",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2019-10-16 23:26:30	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2019-10-16 23:26:33	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	START     Current memory usage: 5685.86 kilobytes.
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache+	 Frame      =
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	Data Averaging: None.
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):data vs. Frequency(6)...
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	Loading page header cache
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	Data selection will yield a total of 3574080 plottable points (flagged and unflagged).
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.0225206 GB of memory (6.3011 bytes/point).
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache+	This is 0.138053% of the memory avail. to CASA (16.3131 GB).
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	Loading chunks......
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	refTime = 2019/01/25/00:00:00.0
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	Finished loading.
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2019-10-16 23:26:34	INFO	PlotMS::load_cache	Axes ranges:
# <br>2019-10-16 23:26:34	INFO	PlotMS::load_cache+	Frequency: 0.890064 to 1.6679 (unflagged); ; 0.935414 to 1.62966 (flagged).
# <br>2019-10-16 23:26:34	INFO	PlotMS::load_cache+	Amp:data: 0 to 271.671 (unflagged); 0 to 1752.54(flagged).
# <br>2019-10-16 23:26:34	INFO	PlotMS::load_cache	Finished indexing.
# <br>2019-10-16 23:26:33	INFO	PlotMS::load_cache	END       Time: +1 seconds.  Memory: +22133.9 kilobytes.
# <br>2019-10-16 23:26:34	INFO	PlotMS::plot	Plotting 2566390 unflagged points.
# <br>2019-10-16 23:26:34	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:26:37	INFO	plotms::::	Exporting the plot.
# <br>2019-10-16 23:26:37	INFO	QPExporter::export	START     Current memory usage: 27959.8 kilobytes.
# <br>2019-10-16 23:26:37	INFO	QPExporter::export	END       Time: +4 seconds.  Memory: +2.04688 kilobytes.
# <br>2019-10-16 23:26:40	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:26:40	INFO	plotms::::	##### End Task: plotms               #####
# <br>2019-10-16 23:26:40	INFO	plotms::::+	##########################################
# </div>

# %% [markdown]
# ## Example 4
#
# Good default conversion:
# Convert only the channels defining the passband and apply antenna based pipeline calibration results to the output MS
# ```
# mvftoms.py https://archive-gw-1.kat.ac.za/1548417874/1548417874_sdp_l0.full.rdb?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJpc3MiOiJrYXQtYXJjaGl2ZS5rYXQuYWMuemEiLCJhdWQiOiJhcmNoaXZlLWd3LTEua2F0LmFjLnphIiwiaWF0IjoxNTcxMjA5MTI2LCJwcmVmaXgiOlsiMTU0ODQxNzg3NCJdLCJleHAiOjE1NzE4MTM5MjYsInN1YiI6ImRldiIsInNjb3BlcyI6WyJyZWFkIl19.2FXdpi0IPYegu3Dvw9DRJitIT7KU3ZpL7jXqPW0kFM9mGHiFLHi10hfBi2uoP1cjNNw92g6ht1PEsELlYK_Gxw -o 1548417874.ms -f -C '163,3885' --flags 'static,cam,data_lost,ingest_rfi' --quack=1 --applycal all
# ```
#
# Options specified:
# * `-f` produce a full polarisation MS in CASA canonical order (HH, HV, VH, VV)
# * `-C` range of frequency channels to keep. Selection is `'163,3885'` which will discard the edges of the band and only use the passband channels during conversion. Refer to the *RFI and Flagging summary* section in the observation calibration report for usable section channels/frequencies
# * `--flags` remove selection of non-usable data and RFI, good default selection `'static,cam,data_lost,ingest_rfi'`
# * `--quack` discard the first N dumps. Refer to the observation summary in the *Description* provided by the MeerKAT archive interface
# * `--applycal` apply `all` available calibration products

# %% [markdown]
# `mvftoms.py https://archive-gw-1.kat.ac.za/1557528200/1557528200_sdp_l0.full.rdb?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJpc3MiOiJrYXQtYXJjaGl2ZS5rYXQuYWMuemEiLCJhdWQiOiJhcmNoaXZlLWd3LTEua2F0LmFjLnphIiwiaWF0IjoxNTcxMjEwNjU2LCJwcmVmaXgiOlsiMTU1NzUyODIwMCJdLCJleHAiOjE1NzE4MTU0NTYsInN1YiI6ImRldiIsInNjb3BlcyI6WyJyZWFkIl19.A-gdRQ-yBpT2lOk1VC9srXtIBTt8XWhbS_j1KgfUDdHCM8dlkWNOYE0-cXcPsOYh3tjVGZbKSyiSAI9vsZ41Qg -o 1557528200.ms -f -a -C '2150,3150' --quack=3 --applycal all`

# %%
msfile = '1557528200.ms'
target = '3C286'
listobs(vis=msfile)
# Out:
# ================================================================================
#            MeasurementSet Name:  /home/jupyter/MeerKAT-Cookbook/utils/1557528200.ms      MS Version 2
# ================================================================================
#    Observer: Lindsay     Project: 20190510-0028
# Observation: MeerKAT
# Data records: 1502730       Total elapsed time = 7772.71 seconds
#    Observed from   10-May-2019/22:43:45.0   to   11-May-2019/00:53:17.8 (UTC)
#
#    ObservationID = 0         ArrayID = 0
#   Date        Timerange (UTC)          Scan  FldId FieldName             nRows     SpwIds   Average Interval(s)    ScanIntent
#   10-May-2019/22:43:45.0 - 22:48:32.9     1      0 PKS1934-63               63720  [0]  [8] [UNKNOWN]
#               22:50:16.9 - 22:55:12.8     2      1 3C286                    65490  [0]  [8] [UNKNOWN]
#               22:56:56.7 - 23:01:44.6     3      0 PKS1934-63               63720  [0]  [8] [UNKNOWN]
#               23:03:36.5 - 23:08:24.4     4      1 3C286                    63720  [0]  [8] [UNKNOWN]
#               23:10:16.4 - 23:15:04.3     5      0 PKS1934-63               63720  [0]  [8] [UNKNOWN]
#               23:16:56.2 - 23:21:44.1     6      1 3C286                    63720  [0]  [8] [UNKNOWN]
#               23:23:36.0 - 23:28:31.9     7      0 PKS1934-63               65490  [0]  [8] [UNKNOWN]
#               23:28:39.9 - 23:33:35.8     8      1 3C286                    65490  [0]  [8] [UNKNOWN]
#               23:35:19.7 - 23:40:15.6     9      0 PKS1934-63               65490  [0]  [8] [UNKNOWN]
#               23:42:07.6 - 23:47:03.4    10      1 3C286                    65490  [0]  [8] [UNKNOWN]
#               23:48:47.4 - 23:53:43.3    11      0 PKS1934-63               65490  [0]  [8] [UNKNOWN]
#               23:53:43.3 - 23:58:47.1    12      0 PKS1934-63               67260  [0]  [8] [UNKNOWN]
#               23:58:47.1 - 00:03:43.0    13      0 PKS1934-63               65490  [0]  [8] [UNKNOWN]
#   11-May-2019/00:03:43.0 - 00:08:46.9    14      0 PKS1934-63               67260  [0]  [8] [UNKNOWN]
#               00:08:46.9 - 00:13:50.8    15      0 PKS1934-63               67260  [0]  [8] [UNKNOWN]
#               00:13:50.8 - 00:18:46.6    16      0 PKS1934-63               65490  [0]  [8] [UNKNOWN]
#               00:18:46.6 - 00:23:50.5    17      0 PKS1934-63               67260  [0]  [8] [UNKNOWN]
#               00:23:50.5 - 00:28:54.4    18      0 PKS1934-63               67260  [0]  [8] [UNKNOWN]
#               00:28:54.4 - 00:33:50.3    19      0 PKS1934-63               65490  [0]  [8] [UNKNOWN]
#               00:33:50.3 - 00:38:54.1    20      0 PKS1934-63               67260  [0]  [8] [UNKNOWN]
#               00:38:54.1 - 00:43:58.0    21      0 PKS1934-63               67260  [0]  [8] [UNKNOWN]
#               00:43:58.0 - 00:49:01.9    22      0 PKS1934-63               67260  [0]  [8] [UNKNOWN]
#               00:49:01.9 - 00:53:17.8    23      0 PKS1934-63               56640  [0]  [8] [UNKNOWN]
#            (nRows = Total number of rows per scan)
# Fields: 2
#   ID   Code Name                RA               Decl           Epoch   SrcId      nRows
#   0    T    PKS1934-63          19:39:25.030000 -63.42.45.70000 J2000   0        1178820
#   1    T    3C286               13:31:08.290000 +30.30.33.00000 J2000   1         323910
# Spectral Windows:  (1 unique spectral windows and 1 unique polarization setups)
#   SpwID  Name   #Chans   Frame   Ch0(MHz)  ChanWid(kHz)  TotBW(kHz) CtrFreq(MHz)  Corrs
#   0      none    1001   TOPO    1305.316       208.984    209193.4   1409.8086   XX  XY  YX  YY
# Sources: 2
#   ID   Name                SpwId RestFreq(MHz)
#   0    PKS1934-63          0     -
#   1    3C286               0     -
#   NB: No systemic velocity information found in SOURCE table.
# Antennas: 60:
#   ID   Name  Station   Diam.    Long.         Lat.                Offset from array center (m)                ITRF Geocentric coordinates (m)
#                                                                      East         North     Elevation               x               y               z
#   0    m000  m000      13.5 m   +021.26.37.7  -30.32.39.3         -9.3284       30.3604       45.2895  5109271.497354  2006808.893028 -3239130.736141
#   1    m001  m001      13.5 m   +021.26.38.0  -30.32.38.1          0.0560       65.8884       45.2670  5109284.854078  2006824.221724 -3239100.126460
#   2    m002  m002      13.5 m   +021.26.36.8  -30.32.39.8        -33.1772       13.4145       45.2882  5109272.199343  2006783.546050 -3239145.330042
#   3    m003  m003      13.5 m   +021.26.35.5  -30.32.39.1        -67.5818       35.3754       44.9929  5109294.928585  2006755.509854 -3239126.266250
#   4    m004  m004      13.5 m   +021.26.33.4  -30.32.40.7       -124.6878      -15.2941       45.0744  5109291.902149  2006692.968027 -3239169.946413
#   5    m005  m005      13.5 m   +021.26.34.2  -30.32.41.7       -103.1522      -45.4691       45.3485  5109269.975114  2006707.493216 -3239196.073499
#   6    m006  m006      13.5 m   +021.26.37.3  -30.32.42.1        -19.2960      -57.7783       45.6250  5109233.717826  2006783.345193 -3239206.815200
#   7    m007  m007      13.5 m   +021.26.34.6  -30.32.45.6        -90.6572     -165.0824       45.8961  5109209.263489  2006697.072283 -3239299.366683
#   8    m008  m008      13.5 m   +021.26.34.5  -30.32.49.9        -94.5934     -297.3768       46.1924  5109148.356361  2006668.921549 -3239413.452183
#   9    m009  m009      13.5 m   +021.26.39.2  -30.32.44.6         31.2922     -133.4077       46.3583  5109180.035241  2006816.610113 -3239272.322421
#   10   m010  m010      13.5 m   +021.26.41.3  -30.32.49.1         87.0321     -274.2252       46.9996  5109093.556556  2006842.526947 -3239393.923881
#   11   m011  m011      13.5 m   +021.26.41.2  -30.32.43.9         82.9473     -114.4301       46.4246  5109170.180559  2006868.236095 -3239256.012063
#   12   m012  m012      13.5 m   +021.26.43.3  -30.32.44.5        138.9552     -130.6192       46.6763  5109142.247324  2006917.437396 -3239270.082552
#   13   m013  m013      13.5 m   +021.26.46.9  -30.32.45.3        235.7287     -155.8122       47.2820  5109095.433207  2007003.019458 -3239292.087312
#   14   m015  m015      13.5 m   +021.26.45.9  -30.32.39.6        209.5771       18.5078       46.3999  5109186.746785  2007010.792885 -3239141.508486
#   15   m016  m016      13.5 m   +021.26.48.8  -30.32.38.6        287.0910       51.7775       46.5569  5109174.267883  2007089.171932 -3239112.934879
#   16   m018  m018      13.5 m   +021.26.42.0  -30.32.40.5        104.6613       -8.2209       46.1106  5109212.230825  2006908.082578 -3239164.381246
#   17   m019  m019      13.5 m   +021.26.44.4  -30.32.41.8        169.7215      -47.5746       46.5393  5109170.171973  2006961.461379 -3239198.492114
#   18   m020  m020      13.5 m   +021.26.41.6  -30.32.42.2         95.9514      -61.9898       46.3020  5109190.134224  2006890.045163 -3239210.786387
#   19   m021  m021      13.5 m   +021.26.26.9  -30.32.43.1       -297.0304      -89.5838       44.4687  5109319.275022  2006518.560600 -3239233.619577
#   20   m022  m022      13.5 m   +021.26.24.0  -30.32.32.5       -374.0553      238.2071       42.9614  5109501.278031  2006507.282330 -3238950.544767
#   21   m023  m023      13.5 m   +021.26.25.9  -30.32.37.2       -323.3654       95.4751       43.7155  5109415.838166  2006528.189133 -3239073.856467
#   22   m025  m025      13.5 m   +021.26.31.2  -30.32.25.3       -183.0330      463.2744       43.0387  5109537.966349  2006726.923649 -3238756.740691
#   23   m026  m026      13.5 m   +021.26.34.3  -30.32.32.0       -100.0650      254.6985       44.1618  5109409.880855  2006765.759243 -3238936.951414
#   24   m027  m027      13.5 m   +021.26.39.5  -30.32.33.3         39.4089      214.5390       44.9260  5109340.506869  2006888.361854 -3238971.927501
#   25   m028  m028      13.5 m   +021.26.36.1  -30.32.35.4        -52.2424      150.4820       44.6795  5109343.517322  2006791.074317 -3239026.971730
#   26   m029  m029      13.5 m   +021.26.34.7  -30.32.36.6        -89.8244      113.5414       44.6358  5109339.748209  2006749.216289 -3239058.764578
#   27   m030  m030      13.5 m   +021.26.44.4  -30.32.28.9        170.2092      351.6010       44.9167  5109357.505327  2007035.572845 -3238853.876338
#   28   m031  m031      13.5 m   +021.26.47.3  -30.32.29.5        245.4927      331.4091       45.0498  5109320.535119  2007101.936893 -3238871.334636
#   29   m033  m033      13.5 m   +021.26.59.8  -30.32.04.6        579.5503     1101.6272       43.5279  5109561.411240  2007555.508268 -3238207.174221
#   30   m034  m034      13.5 m   +021.26.51.4  -30.32.33.5        356.7365      209.3452       46.1986  5109223.044799  2007183.162154 -3238977.047467
#   31   m035  m035      13.5 m   +021.26.52.5  -30.32.38.4        385.0826       56.7586       47.0711  5109141.205385  2007181.466621 -3239108.906281
#   32   m036  m036      13.5 m   +021.26.52.6  -30.32.42.0        387.1910      -53.1071       47.2743  5109088.628952  2007163.076686 -3239203.630401
#   33   m037  m037      13.5 m   +021.26.52.3  -30.32.47.4        379.2259     -221.6588       48.1470  5109012.510055  2007124.614912 -3239349.235774
#   34   m038  m038      13.5 m   +021.26.46.0  -30.32.51.0        212.2485     -331.4330       47.5994  5109021.194393  2006948.629942 -3239443.497067
#   35   m039  m039      13.5 m   +021.26.47.5  -30.32.51.7        252.6894     -354.4998       48.0301  5108995.841451  2006982.118902 -3239463.581377
#   36   m040  m040      13.5 m   +021.26.37.0  -30.32.55.6        -27.9235     -474.5721       47.0754  5109040.863907  2006698.328029 -3239566.503392
#   37   m041  m041      13.5 m   +021.26.27.2  -30.32.54.0       -288.6187     -424.0226       45.3412  5109158.685729  2006464.531149 -3239522.088403
#   38   m042  m042      13.5 m   +021.26.24.4  -30.32.47.4       -362.7829     -222.6584       44.4686  5109280.357027  2006432.636575 -3239348.227095
#   39   m043  m043      13.5 m   +021.26.14.3  -30.32.36.7       -630.9064      109.3516       42.2185  5109533.612995  2006244.029246 -3239061.144609
#   40   m044  m044      13.5 m   +021.26.04.3  -30.32.13.1       -897.1536      838.2027       38.5196  5109972.699387  2006130.375738 -3238431.521767
#   41   m045  m045      13.5 m   +021.25.29.1  -30.32.23.9      -1833.8274      504.5757       38.4618  5110157.095305  2005196.443001 -3238718.843069
#   42   m046  m046      13.5 m   +021.25.42.9  -30.31.35.9      -1468.1271     1989.6994       35.7898  5110723.700942  2005811.697105 -3237438.290580
#   43   m047  m047      13.5 m   +021.26.16.3  -30.32.49.3       -579.3710     -279.6243       43.4387  5109331.745957  2006220.131398 -3239396.763873
#   44   m048  m048      13.5 m   +021.24.52.6  -30.31.05.6      -2805.9422     2924.9023       36.6395  5111655.260922  2004739.749549 -3236633.105248
#   45   m049  m049      13.5 m   +021.24.22.5  -30.32.18.4      -3606.7721      674.7244       42.3158  5110888.066564  2003578.587320 -3238574.254512
#   46   m050  m050      13.5 m   +021.25.20.9  -30.32.59.8      -2053.5026     -605.8529       40.5397  5109713.653487  2004786.468615 -3239676.240087
#   47   m051  m051      13.5 m   +021.26.06.0  -30.32.57.4       -851.3557     -531.6661       42.7515  5109311.351490  2005919.935113 -3239613.475041
#   48   m052  m052      13.5 m   +021.26.15.7  -30.33.09.7       -594.3024     -910.9804       44.5993  5109039.422732  2006089.308403 -3239941.073314
#   49   m053  m053      13.5 m   +021.26.38.4  -30.33.14.8          8.3009    -1066.8173       48.6250  5108748.655700  2006622.471048 -3240077.320541
#   50   m054  m054      13.5 m   +021.27.10.8  -30.32.48.7        870.9294     -262.1368       49.2711  5108814.452029  2007575.084167 -3239384.667574
#   51   m055  m055      13.5 m   +021.27.23.2  -30.32.29.4       1200.6688      334.2015       47.7205  5108974.663302  2007992.339876 -3238870.286700
#   52   m056  m056      13.5 m   +021.27.38.1  -30.32.17.4       1597.2223      704.4331       45.8813  5109003.200202  2008429.669354 -3238550.478204
#   53   m057  m057      13.5 m   +021.26.49.1  -30.30.47.1        293.4830     3497.5902       37.1012  5110793.520952  2007732.149396 -3236139.971630
#   54   m058  m058      13.5 m   +021.28.23.4  -30.31.05.6       2803.9215     2924.8918       42.7345  5109608.665909  2009964.639702 -3236636.209420
#   55   m059  m059      13.5 m   +021.28.56.5  -30.32.08.0       3684.9917      997.1530       52.4668  5108382.618088  2010429.232487 -3238301.702006
#   56   m060  m060      13.5 m   +021.28.46.5  -30.33.32.1       3419.0952    -1602.3087       56.7610  5107254.013472  2009699.357218 -3240542.587341
#   57   m061  m061      13.5 m   +021.26.37.4  -30.33.47.8        -17.4760    -2086.1393       52.1862  5108278.559162  2006410.136906 -3240956.885314
#   58   m062  m062      13.5 m   +021.25.43.9  -30.33.53.6      -1441.9866    -2266.0361       52.2658  5108713.982410  2005051.016549 -3241111.829132
#   59   m063  m063      13.5 m   +021.24.29.5  -30.33.32.1      -3421.1301    -1602.2913       49.4470  5109748.526321  2003331.232039 -3240538.853736
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268404_32" data-target="#log1571268404_32" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268404_32">2019-10-16 23:26:40	INFO	listobs::::
# <br>2019-10-16 23:26:40	INFO	listobs::::+	##########################################
# <br>2019-10-16 23:26:40	INFO	listobs::::+	##### Begin Task: listobs            #####
# <br>2019-10-16 23:26:40	INFO	listobs::::	listobs(vis="1557528200.ms",selectdata=True,spw="",field="",antenna="",
# <br>2019-10-16 23:26:40	INFO	listobs::::+	        uvrange="",timerange="",correlation="",scan="",intent="",
# <br>2019-10-16 23:26:40	INFO	listobs::::+	        feed="",array="",observation="",verbose=True,listfile="casapy_temp.txt",
# <br>2019-10-16 23:26:40	INFO	listobs::::+	        listunfl=False,cachesize=50,overwrite=True)
# <br>2019-10-16 23:26:43	INFO	listobs::ms::summary	Writing output to file: casapy_temp.txt
# <br>2019-10-16 23:26:43	INFO	listobs::MSMetaData::_computeScanAndSubScanProperties 	Computing scan and subscan properties...
# <br>2019-10-16 23:26:44	INFO	listobs::::	##### End Task: listobs              #####
# <br>2019-10-16 23:26:44	INFO	listobs::::+	##########################################
# </div>

# %%
plotms(vis=msfile, xaxis='channel', yaxis='amp', antenna='*&', field=target, averagedata=True, avgtime='30000')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268462_73" data-target="#log1571268462_73" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268462_73">2019-10-16 23:26:44	INFO	plotms::::
# <br>2019-10-16 23:26:44	INFO	plotms::::+	##########################################
# <br>2019-10-16 23:26:44	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2019-10-16 23:26:44	INFO	plotms::::	plotms(vis="1557528200.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        plotindex=0,xaxis="channel",xdatacolumn="",xframe="",xinterp="",
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        yaxis="amp",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        selectdata=True,field="3C286",spw="",timerange="",uvrange="",
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        antenna="*&",scan="",correlation="",array="",observation="",
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        avgtime="30000",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        symboloutline=False,coloraxis="",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2019-10-16 23:26:44	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2019-10-16 23:26:45	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache	START     Current memory usage: 5698.86 kilobytes.
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache+	 Frame      =
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache	Data Averaging:
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache+	 Using VECTOR averaging.
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache+	 Time: 30000 seconds.  Scan: false;  Field: false
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache	Caching for the new plot: Amp(17):data vs. Channel(5)...
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache	Loading page header cache
# <br>2019-10-16 23:26:47	INFO	PlotMS::load_cache	Data selection will yield a total of 35435400 plottable points (flagged and unflagged).
# <br>2019-10-16 23:26:47	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.212779 GB of memory (6.0047 bytes/point).
# <br>2019-10-16 23:26:47	INFO	PlotMS::load_cache+	This is 1.30435% of the memory avail. to CASA (16.3131 GB).
# <br>2019-10-16 23:26:47	INFO	PlotMS::load_cache	Loading chunks......
# <br>2019-10-16 23:27:30	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2019-10-16 23:27:30	INFO	PlotMS::load_cache	refTime = 2019/05/10/00:00:00.0
# <br>2019-10-16 23:27:30	INFO	PlotMS::load_cache	Finished loading.
# <br>2019-10-16 23:27:30	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2019-10-16 23:27:32	INFO	PlotMS::load_cache	Axes ranges:
# <br>2019-10-16 23:27:32	INFO	PlotMS::load_cache+	Channel: 0 to 1000 (unflagged); ; 0 to 923 (flagged).
# <br>2019-10-16 23:27:32	INFO	PlotMS::load_cache+	Amp:data: 0.0767451 to 11.166 (unflagged); 0.0761392 to 30.2783(flagged).
# <br>2019-10-16 23:27:32	INFO	PlotMS::load_cache	Finished indexing.
# <br>2019-10-16 23:26:45	INFO	PlotMS::load_cache	END       Time: +47 seconds.  Memory: +207954 kilobytes.
# <br>2019-10-16 23:27:32	INFO	PlotMS::plot	Plotting 35393872 unflagged points.
# <br>2019-10-16 23:27:32	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:27:37	INFO	plotms::::	Exporting the plot.
# <br>2019-10-16 23:27:37	INFO	QPExporter::export	START     Current memory usage: 213789 kilobytes.
# <br>2019-10-16 23:27:37	INFO	QPExporter::export	END       Time: +5 seconds.  Memory: +1.09375 kilobytes.
# <br>2019-10-16 23:27:43	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:27:43	INFO	plotms::::	##### End Task: plotms               #####
# <br>2019-10-16 23:27:43	INFO	plotms::::+	##########################################
# </div>

# %%
plotms(vis=msfile, xaxis='channel', yaxis='phase', antenna='*&', field=target, averagedata=True, avgtime='30000')
# Out:
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1571268517_35" data-target="#log1571268517_35" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1571268517_35">2019-10-16 23:27:43	INFO	plotms::::
# <br>2019-10-16 23:27:43	INFO	plotms::::+	##########################################
# <br>2019-10-16 23:27:43	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2019-10-16 23:27:43	INFO	plotms::::	plotms(vis="1557528200.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        plotindex=0,xaxis="channel",xdatacolumn="",xframe="",xinterp="",
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        yaxis="phase",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        selectdata=True,field="3C286",spw="",timerange="",uvrange="",
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        antenna="*&",scan="",correlation="",array="",observation="",
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        avgtime="30000",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        symboloutline=False,coloraxis="",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2019-10-16 23:27:43	INFO	plotms::::+	        showatm=False,showtsky=False)
# <br>2019-10-16 23:27:48	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache	START     Current memory usage: 5736.45 kilobytes.
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache	Plot Data Transformations:
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache+	 Frame      =
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache+	 VelDef     = RADIO
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache+	 RestFreq   = 0 MHz
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache+	 dX         = 0 arcsec
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache+	 dY         = 0 arcsec
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache+	 formStokes = false
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache	Data Averaging:
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache+	 Using VECTOR averaging.
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache+	 Time: 30000 seconds.  Scan: false;  Field: false
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache	Plot Data Calibration:
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache+	 Use Calibration    = 0
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache+	 Calibration Library   =
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache	Caching for the new plot: Phase(18):data vs. Channel(5)...
# <br>2019-10-16 23:27:49	INFO	PlotMS::load_cache	Loading page header cache
# <br>2019-10-16 23:27:51	INFO	PlotMS::load_cache	Data selection will yield a total of 35435400 plottable points (flagged and unflagged).
# <br>2019-10-16 23:27:51	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 0.212779 GB of memory (6.0047 bytes/point).
# <br>2019-10-16 23:27:51	INFO	PlotMS::load_cache+	This is 1.30435% of the memory avail. to CASA (16.3131 GB).
# <br>2019-10-16 23:27:51	INFO	PlotMS::load_cache	Loading chunks......
# <br>2019-10-16 23:28:25	INFO	PlotMS::load_cache	Generating the plot mask.
# <br>2019-10-16 23:28:25	INFO	PlotMS::load_cache	refTime = 2019/05/10/00:00:00.0
# <br>2019-10-16 23:28:25	INFO	PlotMS::load_cache	Finished loading.
# <br>2019-10-16 23:28:25	INFO	PlotMS::load_cache	Setting up iteration indexing (if necessary), and calculating plot ranges.
# <br>2019-10-16 23:28:26	INFO	PlotMS::load_cache	Axes ranges:
# <br>2019-10-16 23:28:26	INFO	PlotMS::load_cache+	Channel: 0 to 1000 (unflagged); ; 0 to 923 (flagged).
# <br>2019-10-16 23:28:26	INFO	PlotMS::load_cache+	Phase:data: -180 to 180 (unflagged); -179.998 to 179.999(flagged).
# <br>2019-10-16 23:28:26	INFO	PlotMS::load_cache	Finished indexing.
# <br>2019-10-16 23:27:48	INFO	PlotMS::load_cache	END       Time: +38 seconds.  Memory: +207927 kilobytes.
# <br>2019-10-16 23:28:26	INFO	PlotMS::plot	Plotting 35393872 unflagged points.
# <br>2019-10-16 23:28:26	INFO	plotms::::	Plot file /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:28:32	INFO	plotms::::	Exporting the plot.
# <br>2019-10-16 23:28:32	INFO	QPExporter::export	START     Current memory usage: 213801 kilobytes.
# <br>2019-10-16 23:28:32	INFO	QPExporter::export	END       Time: +6 seconds.  Memory: +0.84375 kilobytes.
# <br>2019-10-16 23:28:37	INFO	PlotMS::plot	Exported /home/jupyter/MeerKAT-Cookbook/utils/plotms_temp.png
# <br>2019-10-16 23:28:37	INFO	plotms::::	##### End Task: plotms               #####
# <br>2019-10-16 23:28:37	INFO	plotms::::+	##########################################
# </div>
